# %% [markdown]
# <a href="https://colab.research.google.com/github/tapan8455/webdeveloping/blob/master/6%20dataSets_Tapan_ML_Project_Skin_Cancer_Classification_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download and Extract dataset

# %% [markdown]
# Dataset Source: https://challenge2018.isic-archive.com/task3/

# %%
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Training_Input.zip
# !unzip -q ISIC2018_Task3_Training_Input.zip
# !rm ISIC2018_Task3_Training_Input.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Training_GroundTruth.zip
# !unzip -q ISIC2018_Task3_Training_GroundTruth.zip
# !rm ISIC2018_Task3_Training_GroundTruth.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Validation_Input.zip
# !unzip -q ISIC2018_Task3_Validation_Input.zip
# !rm ISIC2018_Task3_Validation_Input.zip
# !wget -q https://isic-challenge-data.s3.amazonaws.com/2018/ISIC2018_Task3_Validation_GroundTruth.zip
# !unzip -q ISIC2018_Task3_Validation_GroundTruth.zip
# !rm ISIC2018_Task3_Validation_GroundTruth.zip
# !rm */*.txt

# %%
from tensorflow import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
import keras.layers
import keras.models
import sklearn.model_selection
import sklearn.metrics
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
from keras import backend as K
import shutil
import matplotlib.pyplot as plt
import os
import cv2
# %matplotlib inline

# %% [markdown]
# Reading Training and validation Data

# %%
df_train = pd.read_csv("ISIC2018_Task3_Training_GroundTruth/ISIC2018_Task3_Training_GroundTruth.csv")
df_val = pd.read_csv("ISIC2018_Task3_Validation_GroundTruth/ISIC2018_Task3_Validation_GroundTruth.csv")

# %% [markdown]
# Create Directories to store Training and Validation images

# %%
# !mkdir Train2 Train2/MEL Train2/NV Train2/BCC Train2/AKIEC Train2/BKL Train2/DF Train2/VASC
# !mkdir Validation2 Validation2/MEL Validation2/NV Validation2/BCC Validation2/AKIEC Validation2/BKL Validation2/DF Validation2/VASC

# %% [markdown]
# Sort Training and Validation images into directories earlier created based on class labels from the given .csv files

# %%
for i in range(len(df_train)):
  if df_train["MEL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/MEL")
  if df_train["NV"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/NV")
  if df_train["BCC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/BCC")
  if df_train["AKIEC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/AKIEC")
  if df_train["BKL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/BKL")
  if df_train["DF"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/DF")
  if df_train["VASC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Training_Input/" + df_train["image"][i] + ".jpg", "/content/Train2/VASC")

for i in range(len(df_val)):
  if df_val["MEL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/MEL")
  if df_val["NV"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/NV")
  if df_val["BCC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/BCC")
  if df_val["AKIEC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/AKIEC")
  if df_val["BKL"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/BKL")
  if df_val["DF"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/DF")
  if df_val["VASC"][i] == 1: shutil.move("/content/ISIC2018_Task3_Validation_Input/" + df_val["image"][i] + ".jpg", "/content/Validation2/VASC")

# %%
# !rm -R /content/Train2/NV
# !rm -R /content/Validation2/NV

# %% [markdown]
# Display resized examples from each class

# %%
class_types = ['MEL', 'BCC', 'AKIEC', 'BKL', 'DF', 'VASC']
for class_type in class_types:
  path_of_class = '/content/Train2/' + class_type + '/'
  file_list = os.listdir(path_of_class)
  img_list = []
  for i in range(5):
    image = cv2.imread(path_of_class + file_list[i], cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (100,75))
    img_list.append(image)
  f, axarr = plt.subplots(1,5, figsize=(75, 100))
  print("Class : ", class_type)
  for i in range(5):
    axarr[i].imshow(img_list[i])
  plt.show()
# Out:
# Class :  MEL
# Class :  BCC
# Class :  AKIEC
# Class :  BKL
# Class :  DF
# Class :  VASC

# %% [markdown]
# Read Dataset and augment images. We would use 20% of images from training set as test set

# %%
datagen = ImageDataGenerator(rescale=1./255,
        rotation_range=10,
        zoom_range = 0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        validation_split=0.2) 

datagen2 = ImageDataGenerator(rescale=1./255,
        rotation_range=10,
        zoom_range = 0.1,
        width_shift_range=0.1,
        height_shift_range=0.1)

traingenerator = datagen.flow_from_directory(
        'Train2',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        subset='training',
        class_mode='categorical')

testgenerator = datagen.flow_from_directory(
        'Train2',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        subset='validation',
        class_mode='categorical')

valgenerator = datagen2.flow_from_directory(
        'Validation2',
        target_size=(75, 100),
        seed=0,
        batch_size=100,
        class_mode='categorical')
# Out:
# Found 2651 images belonging to 6 classes.
# Found 659 images belonging to 6 classes.
# Found 70 images belonging to 6 classes.

# %% [markdown]
# Count datapoints (images) from each class

# %%
class_freq = np.unique(traingenerator.classes, return_counts=True)
class_index = traingenerator.class_indices
COUNT_AKIEC, COUNT_BCC, COUNT_BKL, COUNT_DF, COUNT_MEL, COUNT_VASC = class_freq[1]
sns.countplot(traingenerator.classes)
print(class_index)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# {'AKIEC': 0, 'BCC': 1, 'BKL': 2, 'DF': 3, 'MEL': 4, 'VASC': 5}

# %% [markdown]
# As we can see that our data is highly imbalanced, expecially when classes NV and DF are considered

# %%
print("Class name   no. of samples")
for c_name, freq in zip(class_index.keys(), class_freq[1]):
  print("{: >8} {: >10}".format(c_name, freq))
# Out:
# Class name   no. of samples
#    AKIEC        262
#      BCC        412
#      BKL        880
#       DF         92
#      MEL        891
#     VASC        114

# %% [markdown]
# Since our dataset is highly imbalanced, we will use "weighted" approach to training, where we would use inverse of ratios of total samples of a class to total number of samples in the dataset

# %%
TRAIN_IMG_COUNT = len(traingenerator.classes)
weight_for_0 = (1 / COUNT_AKIEC)*(TRAIN_IMG_COUNT)/100
weight_for_1 = (1 / COUNT_BCC)*(TRAIN_IMG_COUNT)/100
weight_for_2 = (1 / COUNT_BKL)*(TRAIN_IMG_COUNT)/100
weight_for_3 = (1 / COUNT_DF)*(TRAIN_IMG_COUNT)/100
weight_for_4 = (1 / COUNT_MEL)*(TRAIN_IMG_COUNT)/100
weight_for_5 = (1 / COUNT_VASC)*(TRAIN_IMG_COUNT)/100
class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3, 4: weight_for_4, 5: weight_for_5}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
# Out:
# Weight for class 0: 0.10
# Weight for class 1: 0.06
# Weight for class 2: 0.03
# Weight for class 3: 0.29
# Weight for class 4: 0.03
# Weight for class 5: 0.23

# %%
def create_model():
  model = tf.keras.models.Sequential()
  model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(75, 100, 3)))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
  model.add(tf.keras.layers.BatchNormalization())

  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(units=2048, activation='relu'))
  model.add(tf.keras.layers.Dropout(0.1))
  model.add(tf.keras.layers.Dense(units=256, activation='relu'))
  model.add(tf.keras.layers.Dense(units=6, activation='softmax'))

  model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy',tf.metrics.Precision(), tf.metrics.Recall(), tf.metrics.AUC(), tf.metrics.AUC(curve='PR')])

  return model

# %% [markdown]
# Minimize val_loss

# %%
model_val_loss = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, mode='min',restore_best_weights=True, verbose=1)
history_val_loss = model_val_loss.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 27/27 [==============================] - 44s 1s/step - loss: 1.2840 - accuracy: 0.4930 - precision: 0.6012 - recall: 0.3350 - auc: 0.8350 - auc_1: 0.5190 - val_loss: 1.7656 - val_accuracy: 0.3143 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5958 - val_auc_1: 0.2656
# Epoch 2/150
# 27/27 [==============================] - 31s 1s/step - loss: 1.0684 - accuracy: 0.5700 - precision: 0.6881 - recall: 0.4195 - auc: 0.8833 - auc_1: 0.6312 - val_loss: 1.6805 - val_accuracy: 0.3143 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6751 - val_auc_1: 0.3107
# Epoch 3/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.9963 - accuracy: 0.6002 - precision: 0.7129 - recall: 0.4730 - auc: 0.8985 - auc_1: 0.6711 - val_loss: 1.8339 - val_accuracy: 0.3143 - val_precision: 0.4167 - val_recall: 0.2143 - val_auc: 0.6178 - val_auc_1: 0.2677
# Epoch 4/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.9448 - accuracy: 0.6228 - precision: 0.7218 - recall: 0.5021 - auc: 0.9092 - auc_1: 0.7059 - val_loss: 2.0227 - val_accuracy: 0.3143 - val_precision: 0.3143 - val_recall: 0.3143 - val_auc: 0.6437 - val_auc_1: 0.3304
# Epoch 5/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.9128 - accuracy: 0.6413 - precision: 0.7122 - recall: 0.5349 - auc: 0.9153 - auc_1: 0.7121 - val_loss: 2.1929 - val_accuracy: 0.4286 - val_precision: 0.4545 - val_recall: 0.2143 - val_auc: 0.6173 - val_auc_1: 0.3036
# Epoch 6/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.8587 - accuracy: 0.6605 - precision: 0.7392 - recall: 0.5538 - auc: 0.9249 - auc_1: 0.7367 - val_loss: 2.1117 - val_accuracy: 0.3286 - val_precision: 0.4545 - val_recall: 0.2143 - val_auc: 0.6443 - val_auc_1: 0.3010
# Epoch 7/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.8772 - accuracy: 0.6515 - precision: 0.7285 - recall: 0.5556 - auc: 0.9213 - auc_1: 0.7241 - val_loss: 2.0630 - val_accuracy: 0.3714 - val_precision: 0.6000 - val_recall: 0.0857 - val_auc: 0.6621 - val_auc_1: 0.3348
# Epoch 8/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8022 - accuracy: 0.6809 - precision: 0.7513 - recall: 0.5937 - auc: 0.9343 - auc_1: 0.7635 - val_loss: 2.6744 - val_accuracy: 0.3143 - val_precision: 0.3143 - val_recall: 0.3143 - val_auc: 0.7236 - val_auc_1: 0.3105
# Epoch 9/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8010 - accuracy: 0.6828 - precision: 0.7462 - recall: 0.5990 - auc: 0.9349 - auc_1: 0.7701 - val_loss: 2.8515 - val_accuracy: 0.3143 - val_precision: 0.3143 - val_recall: 0.3143 - val_auc: 0.7173 - val_auc_1: 0.3738
# Epoch 10/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7774 - accuracy: 0.6952 - precision: 0.7525 - recall: 0.6160 - auc: 0.9383 - auc_1: 0.7774Restoring model weights from the end of the best epoch: 2.
# 27/27 [==============================] - 30s 1s/step - loss: 0.7774 - accuracy: 0.6952 - precision: 0.7525 - recall: 0.6160 - auc: 0.9383 - auc_1: 0.7774 - val_loss: 2.1532 - val_accuracy: 0.3143 - val_precision: 0.3385 - val_recall: 0.3143 - val_auc: 0.7356 - val_auc_1: 0.3809
# Epoch 00010: early stopping

# %%
history_df = pd.DataFrame(history_val_loss.history)
history_df.head(10)
# Out:
#        loss  accuracy  precision  ...  val_recall   val_auc  val_auc_1
# 0  1.284019  0.493021   0.601219  ...    0.000000  0.595755   0.265613
# 1  1.068449  0.569974   0.688119  ...    0.000000  0.675143   0.310717
# 2  0.996335  0.600151   0.712905  ...    0.214286  0.617755   0.267738
# 3  0.944761  0.622784   0.721800  ...    0.314286  0.643694   0.330429
# 4  0.912821  0.641267   0.712205  ...    0.214286  0.617347   0.303554
# 5  0.858725  0.660505   0.739174  ...    0.214286  0.644306   0.301039
# 6  0.877183  0.651452   0.728487  ...    0.085714  0.662122   0.334806
# 7  0.802182  0.680875   0.751313  ...    0.314286  0.723592   0.310502
# 8  0.800978  0.682761   0.746241  ...    0.314286  0.717347   0.373767
# 9  0.777418  0.695209   0.752535  ...    0.314286  0.735633   0.380911
#
# [10 rows x 12 columns]

# %%
eval_val_loss = model_val_loss.evaluate(testgenerator) #early stopping - val_loss
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 1.6895 - accuracy: 0.3323 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6641 - auc_1: 0.2810

# %% [markdown]
# Minimize val_loss - with class weights

# %%
model_val_loss_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, mode='min',restore_best_weights=True, verbose=1)
history_val_loss_weighted = model_val_loss_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback], class_weight=class_weight)
# Out:
# Epoch 1/150
# 27/27 [==============================] - 33s 1s/step - loss: 0.0886 - accuracy: 0.4123 - precision_1: 0.5671 - recall_1: 0.2327 - auc_2: 0.7729 - auc_3: 0.4269 - val_loss: 1.9306 - val_accuracy: 0.0143 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.4107 - val_auc_3: 0.1297
# Epoch 2/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0746 - accuracy: 0.4810 - precision_1: 0.5933 - recall_1: 0.3191 - auc_2: 0.8284 - auc_3: 0.5090 - val_loss: 1.9614 - val_accuracy: 0.0143 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.4445 - val_auc_3: 0.1364
# Epoch 3/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0689 - accuracy: 0.5251 - precision_1: 0.6494 - recall_1: 0.3410 - auc_2: 0.8437 - auc_3: 0.5520 - val_loss: 2.0077 - val_accuracy: 0.1143 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.5526 - val_auc_3: 0.1803
# Epoch 4/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0645 - accuracy: 0.5507 - precision_1: 0.6879 - recall_1: 0.3866 - auc_2: 0.8655 - auc_3: 0.6024 - val_loss: 2.4004 - val_accuracy: 0.1000 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.4596 - val_auc_3: 0.1435
# Epoch 5/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0619 - accuracy: 0.5643 - precision_1: 0.6785 - recall_1: 0.4266 - auc_2: 0.8783 - auc_3: 0.6204 - val_loss: 1.9548 - val_accuracy: 0.3143 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_auc_2: 0.6112 - val_auc_3: 0.2587
# Epoch 6/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0606 - accuracy: 0.5768 - precision_1: 0.6894 - recall_1: 0.4312 - auc_2: 0.8802 - auc_3: 0.6263 - val_loss: 2.0820 - val_accuracy: 0.3143 - val_precision_1: 0.3529 - val_recall_1: 0.0857 - val_auc_2: 0.5920 - val_auc_3: 0.2533
# Epoch 7/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0574 - accuracy: 0.5945 - precision_1: 0.6820 - recall_1: 0.4693 - auc_2: 0.8900 - auc_3: 0.6448 - val_loss: 2.4024 - val_accuracy: 0.1143 - val_precision_1: 0.1429 - val_recall_1: 0.1000 - val_auc_2: 0.5714 - val_auc_3: 0.1832
# Epoch 8/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.0583 - accuracy: 0.5885 - precision_1: 0.6732 - recall_1: 0.4568 - auc_2: 0.8865 - auc_3: 0.6304 - val_loss: 2.3749 - val_accuracy: 0.2000 - val_precision_1: 0.3939 - val_recall_1: 0.1857 - val_auc_2: 0.5611 - val_auc_3: 0.2354
# Epoch 9/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.5824 - precision_1: 0.6709 - recall_1: 0.4760 - auc_2: 0.8909 - auc_3: 0.6446Restoring model weights from the end of the best epoch: 1.
# 27/27 [==============================] - 30s 1s/step - loss: 0.0562 - accuracy: 0.5824 - precision_1: 0.6709 - recall_1: 0.4760 - auc_2: 0.8909 - auc_3: 0.6446 - val_loss: 2.0023 - val_accuracy: 0.3286 - val_precision_1: 0.3958 - val_recall_1: 0.2714 - val_auc_2: 0.6478 - val_auc_3: 0.3478
# Epoch 00009: early stopping

# %%
eval_val_loss_weighted = model_val_loss_weighted.evaluate(testgenerator) #early stopping - val_loss
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 1.9540 - accuracy: 0.0349 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - auc_2: 0.4105 - auc_3: 0.1296

# %% [markdown]
# Maximize val_accuracy

# %%
model_val_accuracy = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_accuracy = model_val_accuracy.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 27/27 [==============================] - 34s 1s/step - loss: 1.2536 - accuracy: 0.4957 - precision_2: 0.6217 - recall_2: 0.3516 - auc_4: 0.8410 - auc_5: 0.5379 - val_loss: 1.6972 - val_accuracy: 0.3714 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_4: 0.6493 - val_auc_5: 0.2834
# Epoch 2/150
# 27/27 [==============================] - 30s 1s/step - loss: 1.0509 - accuracy: 0.5839 - precision_2: 0.6891 - recall_2: 0.4323 - auc_4: 0.8877 - auc_5: 0.6364 - val_loss: 1.6980 - val_accuracy: 0.3143 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_auc_4: 0.6379 - val_auc_5: 0.2834
# Epoch 3/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.9808 - accuracy: 0.6126 - precision_2: 0.7107 - recall_2: 0.4828 - auc_4: 0.9024 - auc_5: 0.6760 - val_loss: 1.8677 - val_accuracy: 0.3143 - val_precision_2: 0.4194 - val_recall_2: 0.1857 - val_auc_4: 0.6231 - val_auc_5: 0.2775
# Epoch 4/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.9332 - accuracy: 0.6303 - precision_2: 0.7245 - recall_2: 0.5168 - auc_4: 0.9116 - auc_5: 0.7031 - val_loss: 2.3228 - val_accuracy: 0.3143 - val_precision_2: 0.3143 - val_recall_2: 0.3143 - val_auc_4: 0.6384 - val_auc_5: 0.2603
# Epoch 5/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.9013 - accuracy: 0.6352 - precision_2: 0.7218 - recall_2: 0.5364 - auc_4: 0.9173 - auc_5: 0.7174 - val_loss: 1.9260 - val_accuracy: 0.3143 - val_precision_2: 0.3143 - val_recall_2: 0.3143 - val_auc_4: 0.6937 - val_auc_5: 0.2859
# Epoch 6/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8919 - accuracy: 0.6413 - precision_2: 0.7144 - recall_2: 0.5330 - auc_4: 0.9192 - auc_5: 0.7156 - val_loss: 3.0517 - val_accuracy: 0.3143 - val_precision_2: 0.3143 - val_recall_2: 0.3143 - val_auc_4: 0.6954 - val_auc_5: 0.2932
# Epoch 7/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8532 - accuracy: 0.6526 - precision_2: 0.7314 - recall_2: 0.5700 - auc_4: 0.9259 - auc_5: 0.7429 - val_loss: 2.9241 - val_accuracy: 0.3143 - val_precision_2: 0.3143 - val_recall_2: 0.3143 - val_auc_4: 0.5811 - val_auc_5: 0.2626
# Epoch 8/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8400 - accuracy: 0.6699 - precision_2: 0.7426 - recall_2: 0.5779 - auc_4: 0.9282 - auc_5: 0.7441 - val_loss: 3.0006 - val_accuracy: 0.3143 - val_precision_2: 0.3143 - val_recall_2: 0.3143 - val_auc_4: 0.6480 - val_auc_5: 0.3631
# Epoch 9/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7910 - accuracy: 0.7031 - precision_2: 0.7533 - recall_2: 0.6069 - auc_4: 0.9362 - auc_5: 0.7681Restoring model weights from the end of the best epoch: 1.
# 27/27 [==============================] - 30s 1s/step - loss: 0.7910 - accuracy: 0.7031 - precision_2: 0.7533 - recall_2: 0.6069 - auc_4: 0.9362 - auc_5: 0.7681 - val_loss: 2.6198 - val_accuracy: 0.3143 - val_precision_2: 0.3188 - val_recall_2: 0.3143 - val_auc_4: 0.6488 - val_auc_5: 0.3237
# Epoch 00009: early stopping

# %%
eval_val_accuracy = model_val_accuracy.evaluate(testgenerator) #early stopping - val_accuracy
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 1.7155 - accuracy: 0.2777 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - auc_4: 0.6245 - auc_5: 0.2381

# %% [markdown]
# Maximize val_accuracy - with class weights

# %%
model_val_accuracy_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_accuracy_weighted = model_val_accuracy_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 27/27 [==============================] - 35s 1s/step - loss: 1.2309 - accuracy: 0.5251 - precision_3: 0.6578 - recall_3: 0.3640 - auc_6: 0.8466 - auc_7: 0.5635 - val_loss: 1.7096 - val_accuracy: 0.4571 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_6: 0.6561 - val_auc_7: 0.3262
# Epoch 2/150
# 27/27 [==============================] - 30s 1s/step - loss: 1.0605 - accuracy: 0.5768 - precision_3: 0.6805 - recall_3: 0.4523 - auc_6: 0.8864 - auc_7: 0.6333 - val_loss: 1.8002 - val_accuracy: 0.3143 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - val_auc_6: 0.6340 - val_auc_7: 0.2983
# Epoch 3/150
# 27/27 [==============================] - 30s 1s/step - loss: 1.0255 - accuracy: 0.5869 - precision_3: 0.6890 - recall_3: 0.4689 - auc_6: 0.8940 - auc_7: 0.6552 - val_loss: 2.2062 - val_accuracy: 0.3143 - val_precision_3: 0.3143 - val_recall_3: 0.3143 - val_auc_6: 0.6296 - val_auc_7: 0.2655
# Epoch 4/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.9725 - accuracy: 0.6107 - precision_3: 0.7109 - recall_3: 0.4832 - auc_6: 0.9039 - auc_7: 0.6868 - val_loss: 1.9401 - val_accuracy: 0.3143 - val_precision_3: 0.3231 - val_recall_3: 0.3000 - val_auc_6: 0.6478 - val_auc_7: 0.3273
# Epoch 5/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8950 - accuracy: 0.6382 - precision_3: 0.7430 - recall_3: 0.5289 - auc_6: 0.9184 - auc_7: 0.7233 - val_loss: 2.1971 - val_accuracy: 0.3000 - val_precision_3: 0.1429 - val_recall_3: 0.0143 - val_auc_6: 0.6233 - val_auc_7: 0.2555
# Epoch 6/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.8630 - accuracy: 0.6696 - precision_3: 0.7486 - recall_3: 0.5639 - auc_6: 0.9242 - auc_7: 0.7364 - val_loss: 2.3186 - val_accuracy: 0.3143 - val_precision_3: 0.5667 - val_recall_3: 0.2429 - val_auc_6: 0.6429 - val_auc_7: 0.3525
# Epoch 7/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.8266 - accuracy: 0.6631 - precision_3: 0.7383 - recall_3: 0.5651 - auc_6: 0.9300 - auc_7: 0.7496 - val_loss: 2.5452 - val_accuracy: 0.3571 - val_precision_3: 0.4186 - val_recall_3: 0.2571 - val_auc_6: 0.6308 - val_auc_7: 0.3047
# Epoch 8/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.7941 - accuracy: 0.6846 - precision_3: 0.7514 - recall_3: 0.5998 - auc_6: 0.9355 - auc_7: 0.7678 - val_loss: 2.2382 - val_accuracy: 0.4714 - val_precision_3: 0.5556 - val_recall_3: 0.2857 - val_auc_6: 0.6704 - val_auc_7: 0.3796
# Epoch 9/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.7857 - accuracy: 0.6911 - precision_3: 0.7652 - recall_3: 0.6024 - auc_6: 0.9367 - auc_7: 0.7704 - val_loss: 2.3824 - val_accuracy: 0.3571 - val_precision_3: 0.4545 - val_recall_3: 0.0714 - val_auc_6: 0.6413 - val_auc_7: 0.3124
# Epoch 10/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.7462 - accuracy: 0.6978 - precision_3: 0.7667 - recall_3: 0.6296 - auc_6: 0.9431 - auc_7: 0.7955 - val_loss: 2.3286 - val_accuracy: 0.3143 - val_precision_3: 0.3175 - val_recall_3: 0.2857 - val_auc_6: 0.6720 - val_auc_7: 0.3476
# Epoch 11/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.7127 - accuracy: 0.7099 - precision_3: 0.7845 - recall_3: 0.6413 - auc_6: 0.9480 - auc_7: 0.8097 - val_loss: 2.9193 - val_accuracy: 0.3857 - val_precision_3: 0.3906 - val_recall_3: 0.3571 - val_auc_6: 0.6506 - val_auc_7: 0.3298
# Epoch 12/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.6978 - accuracy: 0.7243 - precision_3: 0.7768 - recall_3: 0.6484 - auc_6: 0.9498 - auc_7: 0.8119 - val_loss: 2.0209 - val_accuracy: 0.3714 - val_precision_3: 0.3966 - val_recall_3: 0.3286 - val_auc_6: 0.7224 - val_auc_7: 0.3686
# Epoch 13/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.7473 - accuracy: 0.6952 - precision_3: 0.7524 - recall_3: 0.6269 - auc_6: 0.9427 - auc_7: 0.7889 - val_loss: 1.6630 - val_accuracy: 0.5143 - val_precision_3: 0.5472 - val_recall_3: 0.4143 - val_auc_6: 0.7853 - val_auc_7: 0.4830
# Epoch 14/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.6651 - accuracy: 0.7341 - precision_3: 0.7857 - recall_3: 0.6654 - auc_6: 0.9543 - auc_7: 0.8235 - val_loss: 2.5341 - val_accuracy: 0.4571 - val_precision_3: 0.4706 - val_recall_3: 0.4571 - val_auc_6: 0.7338 - val_auc_7: 0.3953
# Epoch 15/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.6598 - accuracy: 0.7424 - precision_3: 0.7912 - recall_3: 0.6877 - auc_6: 0.9550 - auc_7: 0.8280 - val_loss: 1.3870 - val_accuracy: 0.5857 - val_precision_3: 0.5882 - val_recall_3: 0.4286 - val_auc_6: 0.8315 - val_auc_7: 0.5150
# Epoch 16/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.6101 - accuracy: 0.7646 - precision_3: 0.8079 - recall_3: 0.7122 - auc_6: 0.9614 - auc_7: 0.8489 - val_loss: 1.5787 - val_accuracy: 0.4714 - val_precision_3: 0.4697 - val_recall_3: 0.4429 - val_auc_6: 0.8402 - val_auc_7: 0.5003
# Epoch 17/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.5701 - accuracy: 0.7812 - precision_3: 0.8126 - recall_3: 0.7375 - auc_6: 0.9656 - auc_7: 0.8644 - val_loss: 1.3100 - val_accuracy: 0.6000 - val_precision_3: 0.6667 - val_recall_3: 0.5429 - val_auc_6: 0.8654 - val_auc_7: 0.6263
# Epoch 18/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.6151 - accuracy: 0.7714 - precision_3: 0.8102 - recall_3: 0.7197 - auc_6: 0.9611 - auc_7: 0.8529 - val_loss: 1.2233 - val_accuracy: 0.5429 - val_precision_3: 0.6667 - val_recall_3: 0.5429 - val_auc_6: 0.8668 - val_auc_7: 0.5787
# Epoch 19/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.5632 - accuracy: 0.7752 - precision_3: 0.8144 - recall_3: 0.7367 - auc_6: 0.9671 - auc_7: 0.8703 - val_loss: 1.4171 - val_accuracy: 0.5857 - val_precision_3: 0.6290 - val_recall_3: 0.5571 - val_auc_6: 0.8575 - val_auc_7: 0.5469
# Epoch 20/150
# 27/27 [==============================] - 31s 1s/step - loss: 0.5367 - accuracy: 0.7895 - precision_3: 0.8277 - recall_3: 0.7522 - auc_6: 0.9699 - auc_7: 0.8791 - val_loss: 1.2565 - val_accuracy: 0.5857 - val_precision_3: 0.6094 - val_recall_3: 0.5571 - val_auc_6: 0.8780 - val_auc_7: 0.6073
# Epoch 21/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.5022 - accuracy: 0.8110 - precision_3: 0.8371 - recall_3: 0.7774 - auc_6: 0.9729 - auc_7: 0.8891 - val_loss: 1.6901 - val_accuracy: 0.5714 - val_precision_3: 0.5469 - val_recall_3: 0.5000 - val_auc_6: 0.8256 - val_auc_7: 0.5505
# Epoch 22/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.5079 - accuracy: 0.8144 - precision_3: 0.8400 - recall_3: 0.7820 - auc_6: 0.9726 - auc_7: 0.8915 - val_loss: 1.3674 - val_accuracy: 0.6000 - val_precision_3: 0.6613 - val_recall_3: 0.5857 - val_auc_6: 0.8670 - val_auc_7: 0.6060
# Epoch 23/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.4758 - accuracy: 0.8125 - precision_3: 0.8422 - recall_3: 0.7831 - auc_6: 0.9759 - auc_7: 0.9008 - val_loss: 1.9974 - val_accuracy: 0.4143 - val_precision_3: 0.4462 - val_recall_3: 0.4143 - val_auc_6: 0.7957 - val_auc_7: 0.4279
# Epoch 24/150
# 27/27 [==============================] - 30s 1s/step - loss: 0.4511 - accuracy: 0.8269 - precision_3: 0.8508 - recall_3: 0.8042 - auc_6: 0.9780 - auc_7: 0.9078 - val_loss: 1.5233 - val_accuracy: 0.5714 - val_precision_3: 0.5846 - val_recall_3: 0.5429 - val_auc_6: 0.8539 - val_auc_7: 0.5430
# Epoch 25/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.8110 - precision_3: 0.8325 - recall_3: 0.7891 - auc_6: 0.9761 - auc_7: 0.9025Restoring model weights from the end of the best epoch: 17.
# 27/27 [==============================] - 30s 1s/step - loss: 0.4728 - accuracy: 0.8110 - precision_3: 0.8325 - recall_3: 0.7891 - auc_6: 0.9761 - auc_7: 0.9025 - val_loss: 2.2999 - val_accuracy: 0.4429 - val_precision_3: 0.4688 - val_recall_3: 0.4286 - val_auc_6: 0.8039 - val_auc_7: 0.4246
# Epoch 00025: early stopping

# %%
eval_val_accuracy_weighted = model_val_accuracy_weighted.evaluate(testgenerator) #early stopping - val_accuracy
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 1.7807 - accuracy: 0.4310 - precision_3: 0.4560 - recall_3: 0.3778 - auc_6: 0.7905 - auc_7: 0.4337

# %% [markdown]
# Maximize val_recall

# %%
model_val_recall = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_recall', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_recall = model_val_recall.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 27/27 [==============================] - ETA: 0s - loss: 1.2524 - accuracy: 0.4987 - precision_4: 0.6248 - recall_4: 0.3342 - auc_8: 0.8409 - auc_9: 0.5399WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 34s 1s/step - loss: 1.2524 - accuracy: 0.4987 - precision_4: 0.6248 - recall_4: 0.3342 - auc_8: 0.8409 - auc_9: 0.5399 - val_loss: 1.6966 - val_accuracy: 0.3143 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_8: 0.6639 - val_auc_9: 0.3049
# Epoch 2/150
# 27/27 [==============================] - ETA: 0s - loss: 1.0452 - accuracy: 0.5817 - precision_4: 0.6959 - recall_4: 0.4523 - auc_8: 0.8887 - auc_9: 0.6501WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 1.0452 - accuracy: 0.5817 - precision_4: 0.6959 - recall_4: 0.4523 - auc_8: 0.8887 - auc_9: 0.6501 - val_loss: 1.6141 - val_accuracy: 0.3143 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_8: 0.7247 - val_auc_9: 0.3528
# Epoch 3/150
# 27/27 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.6100 - precision_4: 0.7020 - recall_4: 0.4817 - auc_8: 0.8998 - auc_9: 0.6694WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 29s 1s/step - loss: 0.9900 - accuracy: 0.6100 - precision_4: 0.7020 - recall_4: 0.4817 - auc_8: 0.8998 - auc_9: 0.6694 - val_loss: 1.7666 - val_accuracy: 0.4286 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - val_auc_8: 0.6485 - val_auc_9: 0.3316
# Epoch 4/150
# 27/27 [==============================] - ETA: 0s - loss: 0.9424 - accuracy: 0.6171 - precision_4: 0.7136 - recall_4: 0.5085 - auc_8: 0.9097 - auc_9: 0.7019WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 29s 1s/step - loss: 0.9424 - accuracy: 0.6171 - precision_4: 0.7136 - recall_4: 0.5085 - auc_8: 0.9097 - auc_9: 0.7019 - val_loss: 2.1304 - val_accuracy: 0.3143 - val_precision_4: 0.3188 - val_recall_4: 0.3143 - val_auc_8: 0.6582 - val_auc_9: 0.3047
# Epoch 5/150
# 27/27 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.6533 - precision_4: 0.7335 - recall_4: 0.5296 - auc_8: 0.9191 - auc_9: 0.7282WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 29s 1s/step - loss: 0
150
# 27/27 [==============================] - ETA: 0s - loss: 0.5770 - accuracy: 0.7805 - precision_4: 0.8104 - recall_4: 0.7337 - auc_8: 0.9650 - auc_9: 0.8652WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.5770 - accuracy: 0.7805 - precision_4: 0.8104 - recall_4: 0.7337 - auc_8: 0.9650 - auc_9: 0.8652 - val_loss: 1.5389 - val_accuracy: 0.5000 - val_precision_4: 0.5156 - val_recall_4: 0.4714 - val_auc_8: 0.8286 - val_auc_9: 0.4577
# Epoch 20/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.7876 - precision_4: 0.8178 - recall_4: 0.7499 - auc_8: 0.9697 - auc_9: 0.8797WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.5371 - accuracy: 0.7876 - precision_4: 0.8178 - recall_4: 0.7499 - auc_8: 0.9697 - auc_9: 0.8797 - val_loss: 1.2769 - val_accuracy: 0.6143 - val_precision_4: 0.6190 - val_recall_4: 0.5571 - val_auc_8: 0.8741 - val_auc_9: 0.6131
# Epoch 21/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.7846 - precision_4: 0.8159 - recall_4: 0.7575 - auc_8: 0.9706 - auc_9: 0.8828WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.5275 - accuracy: 0.7846 - precision_4: 0.8159 - recall_4: 0.7575 - auc_8: 0.9706 - auc_9: 0.8828 - val_loss: 1.4992 - val_accuracy: 0.5571 - val_precision_4: 0.5625 - val_recall_4: 0.5143 - val_auc_8: 0.8484 - val_auc_9: 0.5247
# Epoch 22/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.8016 - precision_4: 0.8327 - recall_4: 0.7756 - auc_8: 0.9736 - auc_9: 0.8933WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4955 - accuracy: 0.8016 - precision_4: 0.8327 - recall_4: 0.7756 - auc_8: 0.9736 - auc_9: 0.8933 - val_loss: 1.0818 - val_accuracy: 0.5714 - val_precision_4: 0.5606 - val_recall_4: 0.5286 - val_auc_8: 0.8976 - val_auc_9: 0.5936
# Epoch 23/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.8204 - precision_4: 0.8465 - recall_4: 0.7903 - auc_8: 0.9763 - auc_9: 0.9037WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4708 - accuracy: 0.8204 - precision_4: 0.8465 - recall_4: 0.7903 - auc_8: 0.9763 - auc_9: 0.9037 - val_loss: 1.0915 - val_accuracy: 0.6286 - val_precision_4: 0.6667 - val_recall_4: 0.6286 - val_auc_8: 0.9072 - val_auc_9: 0.6183
# Epoch 24/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.8340 - precision_4: 0.8539 - recall_4: 0.8110 - auc_8: 0.9780 - auc_9: 0.9112WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 31s 1s/step - loss: 0.4512 - accuracy: 0.8340 - precision_4: 0.8539 - recall_4: 0.8110 - auc_8: 0.9780 - auc_9: 0.9112 - val_loss: 1.1303 - val_accuracy: 0.6429 - val_precision_4: 0.6406 - val_recall_4: 0.5857 - val_auc_8: 0.8908 - val_auc_9: 0.6465
# Epoch 25/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4443 - accuracy: 0.8257 - precision_4: 0.8463 - recall_4: 0.7978 - auc_8: 0.9785 - auc_9: 0.9106WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4443 - accuracy: 0.8257 - precision_4: 0.8463 - recall_4: 0.7978 - auc_8: 0.9785 - auc_9: 0.9106 - val_loss: 1.2102 - val_accuracy: 0.6857 - val_precision_4: 0.6818 - val_recall_4: 0.6429 - val_auc_8: 0.9016 - val_auc_9: 0.6532
# Epoch 26/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8329 - precision_4: 0.8505 - recall_4: 0.8133 - auc_8: 0.9802 - auc_9: 0.9197WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4278 - accuracy: 0.8329 - precision_4: 0.8505 - recall_4: 0.8133 - auc_8: 0.9802 - auc_9: 0.9197 - val_loss: 1.3080 - val_accuracy: 0.5857 - val_precision_4: 0.5806 - val_recall_4: 0.5143 - val_auc_8: 0.8783 - val_auc_9: 0.6017
# Epoch 27/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8518 - precision_4: 0.8687 - recall_4: 0.8287 - auc_8: 0.9840 - auc_9: 0.9348WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.3819 - accuracy: 0.8518 - precision_4: 0.8687 - recall_4: 0.8287 - auc_8: 0.9840 - auc_9: 0.9348 - val_loss: 1.1395 - val_accuracy: 0.5714 - val_precision_4: 0.5938 - val_recall_4: 0.5429 - val_auc_8: 0.8964 - val_auc_9: 0.6429
# Epoch 28/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8419 - precision_4: 0.8608 - recall_4: 0.8235 - auc_8: 0.9810 - auc_9: 0.9217WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4094 - accuracy: 0.8419 - precision_4: 0.8608 - recall_4: 0.8235 - auc_8: 0.9810 - auc_9: 0.9217 - val_loss: 1.0110 - val_accuracy: 0.6143 - val_precision_4: 0.6290 - val_recall_4: 0.5571 - val_auc_8: 0.9057 - val_auc_9: 0.6857
# Epoch 29/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8612 - precision_4: 0.8784 - recall_4: 0.8393 - auc_8: 0.9847 - auc_9: 0.9375WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.3688 - accuracy: 0.8612 - precision_4: 0.8784 - recall_4: 0.8393 - auc_8: 0.9847 - auc_9: 0.9375 - val_loss: 1.8388 - val_accuracy: 0.4571 - val_precision_4: 0.4923 - val_recall_4: 0.4571 - val_auc_8: 0.8268 - val_auc_9: 0.4825
# Epoch 30/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.8412 - precision_4: 0.8639 - recall_4: 0.8257 - auc_8: 0.9815 - auc_9: 0.9244WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.4092 - accuracy: 0.8412 - precision_4: 0.8639 - recall_4: 0.8257 - auc_8: 0.9815 - auc_9: 0.9244 - val_loss: 1.3792 - val_accuracy: 0.5714 - val_precision_4: 0.5625 - val_recall_4: 0.5143 - val_auc_8: 0.8722 - val_auc_9: 0.5730
# Epoch 31/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8616 - precision_4: 0.8791 - recall_4: 0.8397 - auc_8: 0.9843 - auc_9: 0.9346WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.3760 - accuracy: 0.8616 - precision_4: 0.8791 - recall_4: 0.8397 - auc_8: 0.9843 - auc_9: 0.9346 - val_loss: 1.8457 - val_accuracy: 0.5571 - val_precision_4: 0.5588 - val_recall_4: 0.5429 - val_auc_8: 0.8391 - val_auc_9: 0.5413
# Epoch 32/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.8808 - precision_4: 0.8988 - recall_4: 0.8710 - auc_8: 0.9889 - auc_9: 0.9544WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 31s 1s/step - loss: 0.3097 - accuracy: 0.8808 - precision_4: 0.8988 - recall_4: 0.8710 - auc_8: 0.9889 - auc_9: 0.9544 - val_loss: 1.3304 - val_accuracy: 0.5714 - val_precision_4: 0.5909 - val_recall_4: 0.5571 - val_auc_8: 0.8882 - val_auc_9: 0.6363
# Epoch 33/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3425 - accuracy: 0.8706 - precision_4: 0.8849 - recall_4: 0.8525 - auc_8: 0.9866 - auc_9: 0.9436WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 31s 1s/step - loss: 0
150
# 27/27 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9691 - precision_4: 0.9709 - recall_4: 0.9679 - auc_8: 0.9982 - auc_9: 0.9938WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0853 - accuracy: 0.9691 - precision_4: 0.9709 - recall_4: 0.9679 - auc_8: 0.9982 - auc_9: 0.9938 - val_loss: 1.4794 - val_accuracy: 0.6571 - val_precision_4: 0.6818 - val_recall_4: 0.6429 - val_auc_8: 0.8997 - val_auc_9: 0.7171
# Epoch 129/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9762 - precision_4: 0.9770 - recall_4: 0.9759 - auc_8: 0.9992 - auc_9: 0.9968WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0682 - accuracy: 0.9762 - precision_4: 0.9770 - recall_4: 0.9759 - auc_8: 0.9992 - auc_9: 0.9968 - val_loss: 1.9958 - val_accuracy: 0.6000 - val_precision_4: 0.6087 - val_recall_4: 0.6000 - val_auc_8: 0.8817 - val_auc_9: 0.6657
# Epoch 130/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9751 - precision_4: 0.9758 - recall_4: 0.9736 - auc_8: 0.9985 - auc_9: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0731 - accuracy: 0.9751 - precision_4: 0.9758 - recall_4: 0.9736 - auc_8: 0.9985 - auc_9: 0.9958 - val_loss: 1.6036 - val_accuracy: 0.6429 - val_precision_4: 0.6418 - val_recall_4: 0.6143 - val_auc_8: 0.8936 - val_auc_9: 0.6926
# Epoch 131/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9755 - precision_4: 0.9766 - recall_4: 0.9747 - auc_8: 0.9981 - auc_9: 0.9941WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 31s 1s/step - loss: 0.0816 - accuracy: 0.9755 - precision_4: 0.9766 - recall_4: 0.9747 - auc_8: 0.9981 - auc_9: 0.9941 - val_loss: 2.2398 - val_accuracy: 0.6286 - val_precision_4: 0.6286 - val_recall_4: 0.6286 - val_auc_8: 0.8580 - val_auc_9: 0.5886
# Epoch 132/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9747 - precision_4: 0.9750 - recall_4: 0.9728 - auc_8: 0.9990 - auc_9: 0.9968WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0726 - accuracy: 0.9747 - precision_4: 0.9750 - recall_4: 0.9728 - auc_8: 0.9990 - auc_9: 0.9968 - val_loss: 1.9296 - val_accuracy: 0.6000 - val_precision_4: 0.6087 - val_recall_4: 0.6000 - val_auc_8: 0.8660 - val_auc_9: 0.6527
# Epoch 133/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9777 - precision_4: 0.9792 - recall_4: 0.9751 - auc_8: 0.9990 - auc_9: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0728 - accuracy: 0.9777 - precision_4: 0.9792 - recall_4: 0.9751 - auc_8: 0.9990 - auc_9: 0.9962 - val_loss: 1.4858 - val_accuracy: 0.6714 - val_precision_4: 0.6812 - val_recall_4: 0.6714 - val_auc_8: 0.9082 - val_auc_9: 0.7199
# Epoch 134/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9815 - precision_4: 0.9826 - recall_4: 0.9804 - auc_8: 0.9989 - auc_9: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0612 - accuracy: 0.9815 - precision_4: 0.9826 - recall_4: 0.9804 - auc_8: 0.9989 - auc_9: 0.9962 - val_loss: 1.6745 - val_accuracy: 0.6286 - val_precision_4: 0.6377 - val_recall_4: 0.6286 - val_auc_8: 0.8777 - val_auc_9: 0.6510
# Epoch 135/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9834 - precision_4: 0.9834 - recall_4: 0.9826 - auc_8: 0.9998 - auc_9: 0.9989WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.
ARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_4,recall_4,auc_8,auc_9,val_loss,val_accuracy,val_precision_4,val_recall_4,val_auc_8,val_auc_9
# 27/27 [==============================] - 30s 1s/step - loss: 0.0542 - accuracy: 0.9793 - precision_4: 0.9800 - recall_4: 0.9793 - auc_8: 0.9992 - auc_9: 0.9972 - val_loss: 1.6776 - val_accuracy: 0.6143 - val_precision_4: 0.6324 - val_recall_4: 0.6143 - val_auc_8: 0.8737 - val_auc_9: 0.6389

# %%
eval__val_recall = model_val_recall.evaluate(testgenerator) #early stopping - val_recall
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 1.9364 - accuracy: 0.6009 - precision_4: 0.6087 - recall_4: 0.5948 - auc_8: 0.8638 - auc_9: 0.6206

# %% [markdown]
# Maximize val_recall - with class weights

# %%
model_val_recall_weighted = create_model()
callback = tf.keras.callbacks.EarlyStopping(monitor='val_recall', patience=8, mode='max',restore_best_weights=True, verbose=1)
history_val_recall_weighted = model_val_recall_weighted.fit(traingenerator, validation_data=valgenerator, shuffle=False, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 27/27 [==============================] - ETA: 0s - loss: 1.2702 - accuracy: 0.5040 - precision_5: 0.6326 - recall_5: 0.3572 - auc_10: 0.8379 - auc_11: 0.5304WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 34s 1s/step - loss: 1.2702 - accuracy: 0.5040 - precision_5: 0.6326 - recall_5: 0.3572 - auc_10: 0.8379 - auc_11: 0.5304 - val_loss: 1.7373 - val_accuracy: 0.2143 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_10: 0.5738 - val_auc_11: 0.2169
# Epoch 2/150
# 27/27 [==============================] - ETA: 0s - loss: 1.0606 - accuracy: 0.5737 - precision_5: 0.6729 - recall_5: 0.4236 - auc_10: 0.8854 - auc_11: 0.6278WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 1.0606 - accuracy: 0.5737 - precision_5: 0.6729 - recall_5: 0.4236 - auc_10: 0.8854 - auc_11: 0.6278 - val_loss: 1.7367 - val_accuracy: 0.3143 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00 - val_auc_10: 0.6230 - val_auc_11: 0.2845
# Epoch 3/150
# 27/27 [==============================] - ETA: 0s - loss: 1.0240 - accuracy: 0.5900 - precision_5: 0.6997 - recall_5: 0.4447 - auc_10: 0.8937 - auc_11: 0.6524WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 1.0240 - accuracy: 0.5900 - precision_5: 0.6997 - recall_5: 0.4447 - auc_10: 0.8937 - auc_11: 0.6524 - val_loss: 1.7806 - val_accuracy: 0.3286 - val_precision_5: 0.5000 - val_recall_5: 0.1571 - val_auc_10: 0.6747 - val_auc_11: 0.2982
# Epoch 4/150
# 27/27 [==============================] - ETA: 0s - loss: 0.9517 - accuracy: 0.6220 - precision_5: 0.7054 - recall_5: 0.5040 - auc_10: 0.9081 - auc_11: 0.6915WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.9517 - accuracy: 0.6220 - precision_5: 0.7054 - recall_5: 0.5040 - auc_10: 0.9081 - auc_11: 0.6915 - val_loss: 1.9160 - val_accuracy: 0.3143 - val_precision_5: 0.4524 - val_recall_5: 0.2714 - val_auc_10: 0.6233 - val_auc_11: 0.2882
# Epoch 5/150
# 27/27 [==============================] - ETA: 0s - loss: 0.9031 - accuracy: 0.6413 - precision_5: 0.7255 - recall_5: 0.5315 - auc_10: 0.9170 - auc_11: 0.7118WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.9031 - accuracy: 0.6413 - precision_5: 0.7255 - recall_5: 0.5315 - auc_10: 0.9170 - auc_11: 0.7118 - val_loss: 2.1968 - val_accuracy: 0.1571 - val_precision_5: 0.0857 - val_recall_5: 0.0429 - val_auc_10: 0.5964 - val_auc_11: 0.1960
# Epoch 6/150
# 27/27 [==============================] - ETA: 0s - loss: 0.8778 - accuracy: 0.6420 - precision_5: 0.7129 - recall_5: 0.5394 - auc_10: 0.9214 - auc_11: 0.7248WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.8778 - accuracy: 0.6420 - precision_5: 0.7129 - recall_5: 0.5394 - auc_10: 0.9214 - auc_11: 0.7248 - val_loss: 2.1148 - val_accuracy: 0.3429 - val_precision_5: 0.3958 - val_recall_5: 0.2714 - val_auc_10: 0.6578 - val_auc_11: 0.3729
# Epoch 7/150
# 27/27 [==============================] - ETA: 0s - loss: 0.8745 - accuracy: 0.6465 - precision_5: 0.7255 - recall_5: 0.5492 - auc_10: 0.9222 - auc_11: 0.7288WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.8745 - accuracy: 0.6465 - precision_5: 0.7255 - recall_5: 0.5492 - auc_10: 0.9222 - auc_11: 0.7288 - val_loss: 1.7310 - val_accuracy: 0.4714 - val_precision_5: 0.5000 - val_recall_5: 0.2714 - val_auc_10: 0.7322 - val_auc_11: 0.3503
# Epoch 8/150
# 27/27 [==============================] - ETA: 0s - loss: 0.8177 - accuracy: 0.6782 - precision_5: 0.7483 - recall_5: 0.5911 - auc_10: 0.9318 - auc_11: 0.7590WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.8177 - accuracy: 0.6782 - precision_5: 0.7483 - recall_5: 0.5911 - auc_10: 0.9318 - auc_11: 0.7590 - val_loss: 2.6663 - val_accuracy: 0.3429 - val_precision_5: 0.3382 - val_recall_5: 0.3286 - val_auc_10: 0.6599 - val_auc_11: 0.2939
# Epoch 9/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7924 - accuracy: 0.6986 - precision_5: 0.7540 - recall_5: 0.6164 - auc_10: 0.9357 - auc_11: 0.7664WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.7924 - accuracy: 0.6986 - precision_5: 0.7540 - recall_5: 0.6164 - auc_10: 0.9357 - auc_11: 0.7664 - val_loss: 2.0727 - val_accuracy: 0.3429 - val_precision_5: 0.3438 - val_recall_5: 0.3143 - val_auc_10: 0.7351 - val_auc_11: 0.3264
# Epoch 10/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7806 - accuracy: 0.6956 - precision_5: 0.7594 - recall_5: 0.6228 - auc_10: 0.9378 - auc_11: 0.7775WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.7806 - accuracy: 0.6956 - precision_5: 0.7594 - recall_5: 0.6228 - auc_10: 0.9378 - auc_11: 0.7775 - val_loss: 2.2346 - val_accuracy: 0.4714 - val_precision_5: 0.5085 - val_recall_5: 0.4286 - val_auc_10: 0.6715 - val_auc_11: 0.3984
# Epoch 11/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7661 - accuracy: 0.6967 - precision_5: 0.7547 - recall_5: 0.6198 - auc_10: 0.9399 - auc_11: 0.7794WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.7661 - accuracy: 0.6967 - precision_5: 0.7547 - recall_5: 0.6198 - auc_10: 0.9399 - auc_11: 0.7794 - val_loss: 2.2806 - val_accuracy: 0.4714 - val_precision_5: 0.4918 - val_recall_5: 0.4286 - val_auc_10: 0.7414 - val_auc_11: 0.3764
# Epoch 12/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7050 - precision_5: 0.7724 - recall_5: 0.6273 - auc_10: 0.9439 - auc_11: 0.7928WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.7398 - accuracy: 0.7050 - precision_5: 0.7724 - recall_5: 0.6273 - auc_10: 0.9439 - auc_11: 0.7928 - val_loss: 2.8557 - val_accuracy: 0.4143 - val_precision_5: 0.4118 - val_recall_5: 0.4000 - val_auc_10: 0.7354 - val_auc_11: 0.3982
# Epoch 13/150
# 27/27 [==============================] - ETA: 0s - loss: 0.7185 - accuracy: 0.7141 - precision_5: 0.7666 - recall_5: 0.6454 - auc_10: 0.9469 - auc_11: 0.8034WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.7185 - accuracy: 0.7141 - precision_5: 0.7666 - recall_5: 0.6454 - auc_10: 0.9469 - auc_11: 0.8034 - val_loss: 2.0392 - val_accuracy: 0.4857 - val_precision_5: 0.4603 - val_recall_5: 0.4143 - val_auc_10: 0.7763 - val_auc_11: 0.4192
# Epoch 14/150
# 27/27 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.7295 - precision_5: 0.7872 - recall_5: 0.6643 - auc_10: 0.9524 - auc_11: 0.8198WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.6802 - accuracy: 0.7295 - precision_5: 0.7872 - recall_5: 0.6643 - auc_10: 0.9524 - auc_11: 0.8198 - val_loss: 1.5716 - val_accuracy: 0.4714 - val_precision_5: 0.4762 - val_recall_5: 0.4286 - val_auc_10: 0.8243 - val_auc_11: 0.4501
# Epoch 15/150
# 27/27 [==============================] - ETA: 0s - loss: 0.6982 - accuracy: 0.7258 - precision_5: 0.7734 - recall_5: 0.6680 - auc_10: 0.9496 - auc_11: 0.8114WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.6982 - accuracy: 0.7258 - precision_5: 0.7734 - recall_5: 0.6680 - auc_10: 0.9496 - auc_11: 0.8114 - val_loss: 1.8578 - val_accuracy: 0.4714 - val_precision_5: 0.4500 - val_recall_5: 0.3857 - val_auc_10: 0.8075 - val_auc_11: 0.4585
# Epoch 16/150
# 27/27 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.7529 - precision_5: 0.7967 - recall_5: 0.6918 - auc_10: 0.9565 - auc_11: 0.8320WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.6479 - accuracy: 0.7529 - precision_5: 0.7967 - recall_5: 0.6918 - auc_10: 0.9565 - auc_11: 0.8320 - val_loss: 1.4462 - val_accuracy: 0.4429 - val_precision_5: 0.4500 - val_recall_5: 0.3857 - val_auc_10: 0.8345 - val_auc_11: 0.4196
# Epoch 17/150
# 27/27 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.7548 - precision_5: 0.7987 - recall_5: 0.7095 - auc_10: 0.9590 - auc_11: 0.8377WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.6297 - accuracy: 0.7548 - precision_5: 0.7987 - recall_5: 0.7095 - auc_10: 0.9590 - auc_11: 0.8377 - val_loss: 1.3491 - val_accuracy: 0.5143 - val_precision_5: 0.5660 - val_recall_5: 0.4286 - val_auc_10: 0.8547 - val_auc_11: 0.5523
# Epoch 18/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7763 - precision_5: 0.8074 - recall_5: 0.7386 - auc_10: 0.9658 - auc_11: 0.8639WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.5697 - accuracy: 0.7763 - precision_5: 0.8074 - recall_5: 0.7386 - auc_10: 0.9658 - auc_11: 0.8639 - val_loss: 1.4217 - val_accuracy: 0.4571 - val_precision_5: 0.5614 - val_recall_5: 0.4571 - val_auc_10: 0.8396 - val_auc_11: 0.5076
# Epoch 19/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5667 - accuracy: 0.7733 - precision_5: 0.8113 - recall_5: 0.7329 - auc_10: 0.9663 - auc_11: 0.8661WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.5667 - accuracy: 0.7733 - precision_5: 0.8113 - recall_5: 0.7329 - auc_10: 0.9663 - auc_11: 0.8661 - val_loss: 1.2933 - val_accuracy: 0.4571 - val_precision_5: 0.5263 - val_recall_5: 0.4286 - val_auc_10: 0.8669 - val_auc_11: 0.5798
# Epoch 20/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5646 - accuracy: 0.7703 - precision_5: 0.8072 - recall_5: 0.7390 - auc_10: 0.9664 - auc_11: 0.8646WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.5646 - accuracy: 0.7703 - precision_5: 0.8072 - recall_5: 0.7390 - auc_10: 0.9664 - auc_11: 0.8646 - val_loss: 2.0171 - val_accuracy: 0.5286 - val_precision_5: 0.5455 - val_recall_5: 0.5143 - val_auc_10: 0.8022 - val_auc_11: 0.4626
# Epoch 21/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5647 - accuracy: 0.7767 - precision_5: 0.8125 - recall_5: 0.7405 - auc_10: 0.9660 - auc_11: 0.8697WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.5647 - accuracy: 0.7767 - precision_5: 0.8125 - recall_5: 0.7405 - auc_10: 0.9660 - auc_11: 0.8697 - val_loss: 1.3895 - val_accuracy: 0.5286 - val_precision_5: 0.5500 - val_recall_5: 0.4714 - val_auc_10: 0.8556 - val_auc_11: 0.5780
# Epoch 22/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5429 - accuracy: 0.7857 - precision_5: 0.8207 - recall_5: 0.7458 - auc_10: 0.9690 - auc_11: 0.8726WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.5429 - accuracy: 0.7857 - precision_5: 0.8207 - recall_5: 0.7458 - auc_10: 0.9690 - auc_11: 0.8726 - val_loss: 1.8820 - val_accuracy: 0.4714 - val_precision_5: 0.4697 - val_recall_5: 0.4429 - val_auc_10: 0.8205 - val_auc_11: 0.5109
# Epoch 23/150
# 27/27 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.7952 - precision_5: 0.8285 - recall_5: 0.7620 - auc_10: 0.9709 - auc_11: 0.8839WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.5208 - accuracy: 0.7952 - precision_5: 0.8285 - recall_5: 0.7620 - auc_10: 0.9709 - auc_11: 0.8839 - val_loss: 1.7235 - val_accuracy: 0.4000 - val_precision_5: 0.4262 - val_recall_5: 0.3714 - val_auc_10: 0.8093 - val_auc_11: 0.4580
# Epoch 24/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4866 - accuracy: 0.8084 - precision_5: 0.8317 - recall_5: 0.7756 - auc_10: 0.9746 - auc_11: 0.8956WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.4866 - accuracy: 0.8084 - precision_5: 0.8317 - recall_5: 0.7756 - auc_10: 0.9746 - auc_11: 0.8956 - val_loss: 1.1283 - val_accuracy: 0.6143 - val_precision_5: 0.6000 - val_recall_5: 0.5571 - val_auc_10: 0.8983 - val_auc_11: 0.6656
# Epoch 25/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8242 - precision_5: 0.8469 - recall_5: 0.7971 - auc_10: 0.9781 - auc_11: 0.9094WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.4458 - accuracy: 0.8242 - precision_5: 0.8469 - recall_5: 0.7971 - auc_10: 0.9781 - auc_11: 0.9094 - val_loss: 0.9712 - val_accuracy: 0.6571 - val_precision_5: 0.6875 - val_recall_5: 0.6286 - val_auc_10: 0.9218 - val_auc_11: 0.7064
# Epoch 26/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.8374 - precision_5: 0.8587 - recall_5: 0.8163 - auc_10: 0.9800 - auc_11: 0.9180WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.4267 - accuracy: 0.8374 - precision_5: 0.8587 - recall_5: 0.8163 - auc_10: 0.9800 - auc_11: 0.9180 - val_loss: 1.3736 - val_accuracy: 0.6000 - val_precision_5: 0.6462 - val_recall_5: 0.6000 - val_auc_10: 0.8611 - val_auc_11: 0.6320
# Epoch 27/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.8235 - precision_5: 0.8478 - recall_5: 0.8005 - auc_10: 0.9795 - auc_11: 0.9154WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.4323 - accuracy: 0.8235 - precision_5: 0.8478 - recall_5: 0.8005 - auc_10: 0.9795 - auc_11: 0.9154 - val_loss: 0.8250 - val_accuracy: 0.7000 - val_precision_5: 0.7344 - val_recall_5: 0.6714 - val_auc_10: 0.9353 - val_auc_11: 0.7660
# Epoch 28/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8487 - precision_5: 0.8667 - recall_5: 0.8314 - auc_10: 0.9833 - auc_11: 0.9303WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.3874 - accuracy: 0.8487 - precision_5: 0.8667 - recall_5: 0.8314 - auc_10: 0.9833 - auc_11: 0.9303 - val_loss: 1.7764 - val_accuracy: 0.5286 - val_precision_5: 0.5362 - val_recall_5: 0.5286 - val_auc_10: 0.8547 - val_auc_11: 0.6182
# Epoch 29/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.8536 - precision_5: 0.8683 - recall_5: 0.8280 - auc_10: 0.9838 - auc_11: 0.9308WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.3861 - accuracy: 0.8536 - precision_5: 0.8683 - recall_5: 0.8280 - auc_10: 0.9838 - auc_11: 0.9308 - val_loss: 1.4964 - val_accuracy: 0.6286 - val_precision_5: 0.6349 - val_recall_5: 0.5714 - val_auc_10: 0.8684 - val_auc_11: 0.6314
# Epoch 30/150
# 27/27 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8506 - precision_5: 0.8670 - recall_5: 0.8310 - auc_10: 0.9808 - auc_11: 0.9236WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.4095 - accuracy: 0.8506 - precision_5: 0.8670 - recall_5: 0.8310 - auc_10: 0.9808 - auc_11: 0.9236 - val_loss: 1.9088 - val_accuracy: 0.5571 - val_precision_5: 0.5735 - val_recall_5: 0.5571 - val_auc_10: 0.8361 - val_auc_11: 0.4983
# Epoch 31/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8601 - precision_5: 0.8745 - recall_5: 0.8435 - auc_10: 0.9848 - auc_11: 0.9351WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.3666 - accuracy: 0.8601 - precision_5: 0.8745 - recall_5: 0.8435 - auc_10: 0.9848 - auc_11: 0.9351 - val_loss: 1.2422 - val_accuracy: 0.6571 - val_precision_5: 0.6716 - val_recall_5: 0.6429 - val_auc_10: 0.9008 - val_auc_11: 0.6922
# Epoch 32/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8597 - precision_5: 0.8734 - recall_5: 0.8461 - auc_10: 0.9846 - auc_11: 0.9352WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.3680 - accuracy: 0.8597 - precision_5: 0.8734 - recall_5: 0.8461 - auc_10: 0.9846 - auc_11: 0.9352 - val_loss: 1.7133 - val_accuracy: 0.5571 - val_precision_5: 0.5692 - val_recall_5: 0.5286 - val_auc_10: 0.8577 - val_auc_11: 0.6195
# Epoch 33/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.8653 - precision_5: 0.8824 - recall_5: 0.8491 - auc_10: 0.9873 - auc_11: 0.9461WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 32s 1s/step - loss: 0.3365 - accuracy: 0.8653 - precision_5: 0.8824 - recall_5: 0.8491 - auc_10: 0.9873 - auc_11: 0.9461 - val_loss: 1.3622 - val_accuracy: 0.6143 - val_precision_5: 0.6176 - val_recall_5: 0.6000 - val_auc_10: 0.8866 - val_auc_11: 0.6711
# Epoch 34/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8536 - precision_5: 0.8712 - recall_5: 0.8446 - auc_10: 0.9851 - auc_11: 0.9371WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.3675 - accuracy: 0.8536 - precision_5: 0.8712 - recall_5: 0.8446 - auc_10: 0.9851 - auc_11: 0.9371 - val_loss: 1.3691 - val_accuracy: 0.6286 - val_precision_5: 0.6364 - val_recall_5: 0.6000 - val_auc_10: 0.8803 - val_auc_11: 0.6120
# Epoch 35/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.8748 - precision_5: 0.8876 - recall_5: 0.8578 - auc_10: 0.9865 - auc_11: 0.9429WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.3448 - accuracy: 0.8748 - precision_5: 0.8876 - recall_5: 0.8578 - auc_10: 0.9865 - auc_11: 0.9429 - val_loss: 1.4854 - val_accuracy: 0.6429 - val_precision_5: 0.6269 - val_recall_5: 0.6000 - val_auc_10: 0.8849 - val_auc_11: 0.6110
# Epoch 36/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8763 - precision_5: 0.8884 - recall_5: 0.8676 - auc_10: 0.9875 - auc_11: 0.9495WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.3247 - accuracy: 0.8763 - precision_5: 0.8884 - recall_5: 0.8676 - auc_10: 0.9875 - auc_11: 0.9495 - val_loss: 1.2484 - val_accuracy: 0.6571 - val_precision_5: 0.6667 - val_recall_5: 0.6286 - val_auc_10: 0.8839 - val_auc_11: 0.6977
# Epoch 37/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8797 - precision_5: 0.8925 - recall_5: 0.8676 - auc_10: 0.9903 - auc_11: 0.9576WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2944 - accuracy: 0.8797 - precision_5: 0.8925 - recall_5: 0.8676 - auc_10: 0.9903 - auc_11: 0.9576 - val_loss: 1.0429 - val_accuracy: 0.6000 - val_precision_5: 0.6119 - val_recall_5: 0.5857 - val_auc_10: 0.9121 - val_auc_11: 0.6999
# Epoch 38/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.8940 - precision_5: 0.9046 - recall_5: 0.8838 - auc_10: 0.9896 - auc_11: 0.9557WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2918 - accuracy: 0.8940 - precision_5: 0.9046 - recall_5: 0.8838 - auc_10: 0.9896 - auc_11: 0.9557 - val_loss: 1.6563 - val_accuracy: 0.5714 - val_precision_5: 0.5714 - val_recall_5: 0.5714 - val_auc_10: 0.8812 - val_auc_11: 0.6436
# Epoch 39/150
# 27/27 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.8853 - precision_5: 0.8957 - recall_5: 0.8778 - auc_10: 0.9889 - auc_11: 0.9538WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.3073 - accuracy: 0.8853 - precision_5: 0.8957 - recall_5: 0.8778 - auc_10: 0.9889 - auc_11: 0.9538 - val_loss: 1.2918 - val_accuracy: 0.6429 - val_precision_5: 0.6667 - val_recall_5: 0.6286 - val_auc_10: 0.8969 - val_auc_11: 0.6717
# Epoch 40/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.8966 - precision_5: 0.9043 - recall_5: 0.8872 - auc_10: 0.9902 - auc_11: 0.9599WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.2796 - accuracy: 0.8966 - precision_5: 0.9043 - recall_5: 0.8872 - auc_10: 0.9902 - auc_11: 0.9599 - val_loss: 1.3171 - val_accuracy: 0.7000 - val_precision_5: 0.7059 - val_recall_5: 0.6857 - val_auc_10: 0.8844 - val_auc_11: 0.6931
# Epoch 41/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9091 - precision_5: 0.9150 - recall_5: 0.8978 - auc_10: 0.9929 - auc_11: 0.9686WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2470 - accuracy: 0.9091 - precision_5: 0.9150 - recall_5: 0.8978 - auc_10: 0.9929 - auc_11: 0.9686 - val_loss: 1.8731 - val_accuracy: 0.6286 - val_precision_5: 0.6471 - val_recall_5: 0.6286 - val_auc_10: 0.8590 - val_auc_11: 0.6145
# Epoch 42/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2596 - accuracy: 0.9012 - precision_5: 0.9084 - recall_5: 0.8936 - auc_10: 0.9915 - auc_11: 0.9654WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2596 - accuracy: 0.9012 - precision_5: 0.9084 - recall_5: 0.8936 - auc_10: 0.9915 - auc_11: 0.9654 - val_loss: 1.5609 - val_accuracy: 0.6000 - val_precision_5: 0.6212 - val_recall_5: 0.5857 - val_auc_10: 0.8654 - val_auc_11: 0.5972
# Epoch 43/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.8925 - precision_5: 0.9000 - recall_5: 0.8857 - auc_10: 0.9909 - auc_11: 0.9615WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2784 - accuracy: 0.8925 - precision_5: 0.9000 - recall_5: 0.8857 - auc_10: 0.9909 - auc_11: 0.9615 - val_loss: 1.5939 - val_accuracy: 0.5000 - val_precision_5: 0.5312 - val_recall_5: 0.4857 - val_auc_10: 0.8460 - val_auc_11: 0.5250
# Epoch 44/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 0.9132 - precision_5: 0.9222 - recall_5: 0.9031 - auc_10: 0.9928 - auc_11: 0.9708WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2358 - accuracy: 0.9132 - precision_5: 0.9222 - recall_5: 0.9031 - auc_10: 0.9928 - auc_11: 0.9708 - val_loss: 2.1919 - val_accuracy: 0.6286 - val_precision_5: 0.6212 - val_recall_5: 0.5857 - val_auc_10: 0.8271 - val_auc_11: 0.5698
# Epoch 45/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9227 - precision_5: 0.9278 - recall_5: 0.9159 - auc_10: 0.9934 - auc_11: 0.9744WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2209 - accuracy: 0.9227 - precision_5: 0.9278 - recall_5: 0.9159 - auc_10: 0.9934 - auc_11: 0.9744 - val_loss: 1.6048 - val_accuracy: 0.5429 - val_precision_5: 0.5507 - val_recall_5: 0.5429 - val_auc_10: 0.8503 - val_auc_11: 0.5782
# Epoch 46/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.8974 - precision_5: 0.9029 - recall_5: 0.8906 - auc_10: 0.9917 - auc_11: 0.9649WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2652 - accuracy: 0.8974 - precision_5: 0.9029 - recall_5: 0.8906 - auc_10: 0.9917 - auc_11: 0.9649 - val_loss: 2.0234 - val_accuracy: 0.5000 - val_precision_5: 0.5469 - val_recall_5: 0.5000 - val_auc_10: 0.8130 - val_auc_11: 0.5009
# Epoch 47/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.9166 - precision_5: 0.9259 - recall_5: 0.9102 - auc_10: 0.9938 - auc_11: 0.9753WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2249 - accuracy: 0.9166 - precision_5: 0.9259 - recall_5: 0.9102 - auc_10: 0.9938 - auc_11: 0.9753 - val_loss: 1.2540 - val_accuracy: 0.6143 - val_precision_5: 0.6562 - val_recall_5: 0.6000 - val_auc_10: 0.8986 - val_auc_11: 0.6866
# Epoch 48/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9363 - precision_5: 0.9389 - recall_5: 0.9325 - auc_10: 0.9965 - auc_11: 0.9838WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1715 - accuracy: 0.9363 - precision_5: 0.9389 - recall_5: 0.9325 - auc_10: 0.9965 - auc_11: 0.9838 - val_loss: 1.5766 - val_accuracy: 0.7000 - val_precision_5: 0.7121 - val_recall_5: 0.6714 - val_auc_10: 0.8799 - val_auc_11: 0.6365
# Epoch 49/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9310 - precision_5: 0.9414 - recall_5: 0.9276 - auc_10: 0.9949 - auc_11: 0.9784WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1893 - accuracy: 0.9310 - precision_5: 0.9414 - recall_5: 0.9276 - auc_10: 0.9949 - auc_11: 0.9784 - val_loss: 1.2448 - val_accuracy: 0.6571 - val_precision_5: 0.6667 - val_recall_5: 0.6571 - val_auc_10: 0.9137 - val_auc_11: 0.7356
# Epoch 50/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9166 - precision_5: 0.9212 - recall_5: 0.9125 - auc_10: 0.9946 - auc_11: 0.9768WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2170 - accuracy: 0.9166 - precision_5: 0.9212 - recall_5: 0.9125 - auc_10: 0.9946 - auc_11: 0.9768 - val_loss: 2.0656 - val_accuracy: 0.5286 - val_precision_5: 0.5538 - val_recall_5: 0.5143 - val_auc_10: 0.8341 - val_auc_11: 0.5595
# Epoch 51/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9189 - precision_5: 0.9262 - recall_5: 0.9132 - auc_10: 0.9932 - auc_11: 0.9728WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2236 - accuracy: 0.9189 - precision_5: 0.9262 - recall_5: 0.9132 - auc_10: 0.9932 - auc_11: 0.9728 - val_loss: 1.4061 - val_accuracy: 0.5143 - val_precision_5: 0.5077 - val_recall_5: 0.4714 - val_auc_10: 0.8898 - val_auc_11: 0.6189
# Epoch 52/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9329 - precision_5: 0.9389 - recall_5: 0.9268 - auc_10: 0.9948 - auc_11: 0.9793WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1907 - accuracy: 0.9329 - precision_5: 0.9389 - recall_5: 0.9268 - auc_10: 0.9948 - auc_11: 0.9793 - val_loss: 1.6788 - val_accuracy: 0.6000 - val_precision_5: 0.6087 - val_recall_5: 0.6000 - val_auc_10: 0.8658 - val_auc_11: 0.6377
# Epoch 53/150
# 27/27 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9257 - precision_5: 0.9294 - recall_5: 0.9189 - auc_10: 0.9949 - auc_11: 0.9776WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.2061 - accuracy: 0.9257 - precision_5: 0.9294 - recall_5: 0.9189 - auc_10: 0.9949 - auc_11: 0.9776 - val_loss: 1.6985 - val_accuracy: 0.5714 - val_precision_5: 0.5797 - val_recall_5: 0.5714 - val_auc_10: 0.8691 - val_auc_11: 0.6077
# Epoch 54/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9336 - precision_5: 0.9394 - recall_5: 0.9291 - auc_10: 0.9950 - auc_11: 0.9808WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.1797 - accuracy: 0.9336 - precision_5: 0.9394 - recall_5: 0.9291 - auc_10: 0.9950 - auc_11: 0.9808 - val_loss: 2.6096 - val_accuracy: 0.5286 - val_precision_5: 0.5441 - val_recall_5: 0.5286 - val_auc_10: 0.8055 - val_auc_11: 0.4971
# Epoch 55/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9487 - precision_5: 0.9540 - recall_5: 0.9461 - auc_10: 0.9972 - auc_11: 0.9892WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.1356 - accuracy: 0.9487 - precision_5: 0.9540 - recall_5: 0.9461 - auc_10: 0.9972 - auc_11: 0.9892 - val_loss: 1.8917 - val_accuracy: 0.5571 - val_precision_5: 0.5571 - val_recall_5: 0.5571 - val_auc_10: 0.8837 - val_auc_11: 0.6339
# Epoch 56/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9468 - precision_5: 0.9484 - recall_5: 0.9427 - auc_10: 0.9963 - auc_11: 0.9854WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.1518 - accuracy: 0.9468 - precision_5: 0.9484 - recall_5: 0.9427 - auc_10: 0.9963 - auc_11: 0.9854 - val_loss: 1.3643 - val_accuracy: 0.6571 - val_precision_5: 0.6719 - val_recall_5: 0.6143 - val_auc_10: 0.9162 - val_auc_11: 0.7434
# Epoch 57/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9340 - precision_5: 0.9374 - recall_5: 0.9313 - auc_10: 0.9963 - auc_11: 0.9847WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.1621 - accuracy: 0.9340 - precision_5: 0.9374 - recall_5: 0.9313 - auc_10: 0.9963 - auc_11: 0.9847 - val_loss: 1.1406 - val_accuracy: 0.7286 - val_precision_5: 0.7286 - val_recall_5: 0.7286 - val_auc_10: 0.9329 - val_auc_11: 0.7868
# Epoch 58/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9412 - precision_5: 0.9438 - recall_5: 0.9381 - auc_10: 0.9973 - auc_11: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.1512 - accuracy: 0.9412 - precision_5: 0.9438 - recall_5: 0.9381 - auc_10: 0.9973 - auc_11: 0.9882 - val_loss: 2.1208 - val_accuracy: 0.6143 - val_precision_5: 0.6232 - val_recall_5: 0.6143 - val_auc_10: 0.8600 - val_auc_11: 0.6176
# Epoch 59/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9253 - precision_5: 0.9307 - recall_5: 0.9223 - auc_10: 0.9960 - auc_11: 0.9823WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1819 - accuracy: 0.9253 - precision_5: 0.9307 - recall_5: 0.9223 - auc_10: 0.9960 - auc_11: 0.9823 - val_loss: 1.6167 - val_accuracy: 0.6857 - val_precision_5: 0.6970 - val_recall_5: 0.6571 - val_auc_10: 0.8987 - val_auc_11: 0.7506
# Epoch 60/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9442 - precision_5: 0.9476 - recall_5: 0.9408 - auc_10: 0.9962 - auc_11: 0.9860WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1591 - accuracy: 0.9442 - precision_5: 0.9476 - recall_5: 0.9408 - auc_10: 0.9962 - auc_11: 0.9860 - val_loss: 1.7898 - val_accuracy: 0.6714 - val_precision_5: 0.6765 - val_recall_5: 0.6571 - val_auc_10: 0.8681 - val_auc_11: 0.7034
# Epoch 61/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9476 - precision_5: 0.9510 - recall_5: 0.9445 - auc_10: 0.9967 - auc_11: 0.9860WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1484 - accuracy: 0.9476 - precision_5: 0.9510 - recall_5: 0.9445 - auc_10: 0.9967 - auc_11: 0.9860 - val_loss: 1.3836 - val_accuracy: 0.6286 - val_precision_5: 0.6471 - val_recall_5: 0.6286 - val_auc_10: 0.8941 - val_auc_11: 0.7027
# Epoch 62/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9498 - precision_5: 0.9525 - recall_5: 0.9445 - auc_10: 0.9972 - auc_11: 0.9887WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1398 - accuracy: 0.9498 - precision_5: 0.9525 - recall_5: 0.9445 - auc_10: 0.9972 - auc_11: 0.9887 - val_loss: 2.0896 - val_accuracy: 0.6286 - val_precision_5: 0.6269 - val_recall_5: 0.6000 - val_auc_10: 0.8435 - val_auc_11: 0.5736
# Epoch 63/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9547 - precision_5: 0.9565 - recall_5: 0.9532 - auc_10: 0.9976 - auc_11: 0.9898WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1240 - accuracy: 0.9547 - precision_5: 0.9565 - recall_5: 0.9532 - auc_10: 0.9976 - auc_11: 0.9898 - val_loss: 1.6137 - val_accuracy: 0.7143 - val_precision_5: 0.7101 - val_recall_5: 0.7000 - val_auc_10: 0.8942 - val_auc_11: 0.7223
# Epoch 64/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9510 - precision_5: 0.9537 - recall_5: 0.9483 - auc_10: 0.9969 - auc_11: 0.9885WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1385 - accuracy: 0.9510 - precision_5: 0.9537 - recall_5: 0.9483 - auc_10: 0.9969 - auc_11: 0.9885 - val_loss: 1.5816 - val_accuracy: 0.6000 - val_precision_5: 0.6087 - val_recall_5: 0.6000 - val_auc_10: 0.8974 - val_auc_11: 0.6651
# Epoch 65/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9483 - precision_5: 0.9504 - recall_5: 0.9464 - auc_10: 0.9970 - auc_11: 0.9878WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1422 - accuracy: 0.9483 - precision_5: 0.9504 - recall_5: 0.9464 - auc_10: 0.9970 - auc_11: 0.9878 - val_loss: 1.4733 - val_accuracy: 0.6571 - val_precision_5: 0.6716 - val_recall_5: 0.6429 - val_auc_10: 0.8860 - val_auc_11: 0.6871
# Epoch 66/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9555 - precision_5: 0.9575 - recall_5: 0.9528 - auc_10: 0.9975 - auc_11: 0.9897WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.1234 - accuracy: 0.9555 - precision_5: 0.9575 - recall_5: 0.9528 - auc_10: 0.9975 - auc_11: 0.9897 - val_loss: 1.2581 - val_accuracy: 0.6429 - val_precision_5: 0.6471 - val_recall_5: 0.6286 - val_auc_10: 0.9170 - val_auc_11: 0.7198
# Epoch 67/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9461 - precision_5: 0.9473 - recall_5: 0.9434 - auc_10: 0.9964 - auc_11: 0.9859WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1531 - accuracy: 0.9461 - precision_5: 0.9473 - recall_5: 0.9434 - auc_10: 0.9964 - auc_11: 0.9859 - val_loss: 1.5180 - val_accuracy: 0.6286 - val_precision_5: 0.6232 - val_recall_5: 0.6143 - val_auc_10: 0.8771 - val_auc_11: 0.6460
# Epoch 68/150
# 27/27 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9412 - precision_5: 0.9445 - recall_5: 0.9370 - auc_10: 0.9961 - auc_11: 0.9842WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.1665 - accuracy: 0.9412 - precision_5: 0.9445 - recall_5: 0.9370 - auc_10: 0.9961 - auc_11: 0.9842 - val_loss: 1.4511 - val_accuracy: 0.6000 - val_precision_5: 0.6061 - val_recall_5: 0.5714 - val_auc_10: 0.8747 - val_auc_11: 0.6379
# Epoch 69/150
# ...
# 27/27 [==============================] - 30s 1s/step - loss: 0.0588 - accuracy: 0.9800 - precision_5: 0.9807 - recall_5: 0.9789 - auc_10: 0.9996 - auc_11: 0.9980 - val_loss: 1.6811 - val_accuracy: 0.6143 - val_precision_5: 0.6462 - val_recall_5: 0.6000 - val_auc_10: 0.8927 - val_auc_11: 0.6670
# Epoch 129/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9834 - precision_5: 0.9838 - recall_5: 0.9830 - auc_10: 0.9991 - auc_11: 0.9976WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0519 - accuracy: 0.9834 - precision_5: 0.9838 - recall_5: 0.9830 - auc_10: 0.9991 - auc_11: 0.9976 - val_loss: 2.3695 - val_accuracy: 0.5714 - val_precision_5: 0.5882 - val_recall_5: 0.5714 - val_auc_10: 0.8437 - val_auc_11: 0.5846
# Epoch 130/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9736 - precision_5: 0.9743 - recall_5: 0.9725 - auc_10: 0.9971 - auc_11: 0.9911WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0933 - accuracy: 0.9736 - precision_5: 0.9743 - recall_5: 0.9725 - auc_10: 0.9971 - auc_11: 0.9911 - val_loss: 1.9123 - val_accuracy: 0.6286 - val_precision_5: 0.6418 - val_recall_5: 0.6143 - val_auc_10: 0.8705 - val_auc_11: 0.6257
# Epoch 131/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9691 - precision_5: 0.9701 - recall_5: 0.9683 - auc_10: 0.9980 - auc_11: 0.9931WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0956 - accuracy: 0.9691 - precision_5: 0.9701 - recall_5: 0.9683 - auc_10: 0.9980 - auc_11: 0.9931 - val_loss: 1.7912 - val_accuracy: 0.6286 - val_precision_5: 0.6471 - val_recall_5: 0.6286 - val_auc_10: 0.8856 - val_auc_11: 0.7041
# Epoch 132/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9755 - precision_5: 0.9766 - recall_5: 0.9743 - auc_10: 0.9982 - auc_11: 0.9937WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0781 - accuracy: 0.9755 - precision_5: 0.9766 - recall_5: 0.9743 - auc_10: 0.9982 - auc_11: 0.9937 - val_loss: 1.4899 - val_accuracy: 0.6714 - val_precision_5: 0.6812 - val_recall_5: 0.6714 - val_auc_10: 0.8871 - val_auc_11: 0.6884
# Epoch 133/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9785 - precision_5: 0.9788 - recall_5: 0.9770 - auc_10: 0.9996 - auc_11: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0607 - accuracy: 0.9785 - precision_5: 0.9788 - recall_5: 0.9770 - auc_10: 0.9996 - auc_11: 0.9979 - val_loss: 1.5580 - val_accuracy: 0.7000 - val_precision_5: 0.7059 - val_recall_5: 0.6857 - val_auc_10: 0.9069 - val_auc_11: 0.7188
# Epoch 134/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9872 - precision_5: 0.9875 - recall_5: 0.9860 - auc_10: 0.9991 - auc_11: 0.9972WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 29s 1s/step - loss: 0.0426 - accuracy: 0.9872 - precision_5: 0.9875 - recall_5: 0.9860 - auc_10: 0.9991 - auc_11: 0.9972 - val_loss: 2.0348 - val_accuracy: 0.6143 - val_precision_5: 0.6232 - val_recall_5: 0.6143 - val_auc_10: 0.8556 - val_auc_11: 0.5932
# Epoch 135/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9845 - precision_5: 0.9853 - recall_5: 0.9838 - auc_10: 0.9993 - auc_11: 0.9979WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0496 - accuracy: 0.9845 - precision_5: 0.9853 - recall_5: 0.9838 - auc_10: 0.9993 - auc_11: 0.9979 - val_loss: 2.0188 - val_accuracy: 0.6429 - val_precision_5: 0.6522 - val_recall_5: 0.6429 - val_auc_10: 0.8562 - val_auc_11: 0.6474
# Epoch 136/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9796 - precision_5: 0.9803 - recall_5: 0.9785 - auc_10: 0.9992 - auc_11: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0581 - accuracy: 0.9796 - precision_5: 0.9803 - recall_5: 0.9785 - auc_10: 0.9992 - auc_11: 0.9970 - val_loss: 1.6813 - val_accuracy: 0.6714 - val_precision_5: 0.6714 - val_recall_5: 0.6714 - val_auc_10: 0.8777 - val_auc_11: 0.6719
# Epoch 137/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9747 - precision_5: 0.9773 - recall_5: 0.9743 - auc_10: 0.9979 - auc_11: 0.9933WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0855 - accuracy: 0.9747 - precision_5: 0.9773 - recall_5: 0.9743 - auc_10: 0.9979 - auc_11: 0.9933 - val_loss: 1.9557 - val_accuracy: 0.5857 - val_precision_5: 0.5857 - val_recall_5: 0.5857 - val_auc_10: 0.8716 - val_auc_11: 0.6377
# Epoch 138/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9713 - precision_5: 0.9721 - recall_5: 0.9710 - auc_10: 0.9987 - auc_11: 0.9956WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0816 - accuracy: 0.9713 - precision_5: 0.9721 - recall_5: 0.9710 - auc_10: 0.9987 - auc_11: 0.9956 - val_loss: 1.8568 - val_accuracy: 0.6000 - val_precision_5: 0.6176 - val_recall_5: 0.6000 - val_auc_10: 0.8749 - val_auc_11: 0.6080
# Epoch 139/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9713 - precision_5: 0.9728 - recall_5: 0.9702 - auc_10: 0.9990 - auc_11: 0.9959WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0804 - accuracy: 0.9713 - precision_5: 0.9728 - recall_5: 0.9702 - auc_10: 0.9990 - auc_11: 0.9959 - val_loss: 1.0423 - val_accuracy: 0.7429 - val_precision_5: 0.7424 - val_recall_5: 0.7000 - val_auc_10: 0.9269 - val_auc_11: 0.8021
# Epoch 140/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9796 - precision_5: 0.9803 - recall_5: 0.9785 - auc_10: 0.9993 - auc_11: 0.9969WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0634 - accuracy: 0.9796 - precision_5: 0.9803 - recall_5: 0.9785 - auc_10: 0.9993 - auc_11: 0.9969 - val_loss: 2.5930 - val_accuracy: 0.5286 - val_precision_5: 0.5362 - val_recall_5: 0.5286 - val_auc_10: 0.8149 - val_auc_11: 0.4979
# Epoch 141/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9800 - precision_5: 0.9804 - recall_5: 0.9793 - auc_10: 0.9991 - auc_11: 0.9970WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0595 - accuracy: 0.9800 - precision_5: 0.9804 - recall_5: 0.9793 - auc_10: 0.9991 - auc_11: 0.9970 - val_loss: 1.4755 - val_accuracy: 0.6286 - val_precision_5: 0.6471 - val_recall_5: 0.6286 - val_auc_10: 0.9123 - val_auc_11: 0.7010
# Epoch 142/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9789 - precision_5: 0.9796 - recall_5: 0.9777 - auc_10: 0.9987 - auc_11: 0.9957WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0605 - accuracy: 0.9789 - precision_5: 0.9796 - recall_5: 0.9777 - auc_10: 0.9987 - auc_11: 0.9957 - val_loss: 2.0863 - val_accuracy: 0.5857 - val_precision_5: 0.6029 - val_recall_5: 0.5857 - val_auc_10: 0.8529 - val_auc_11: 0.6116
# Epoch 143/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9823 - precision_5: 0.9838 - recall_5: 0.9823 - auc_10: 0.9998 - auc_11: 0.9990WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0436 - accuracy: 0.9823 - precision_5: 0.9838 - recall_5: 0.9823 - auc_10: 0.9998 - auc_11: 0.9990 - val_loss: 1.4017 - val_accuracy: 0.7000 - val_precision_5: 0.7015 - val_recall_5: 0.6714 - val_auc_10: 0.8977 - val_auc_11: 0.6999
# Epoch 144/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9842 - precision_5: 0.9853 - recall_5: 0.9834 - auc_10: 0.9990 - auc_11: 0.9967WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0505 - accuracy: 0.9842 - precision_5: 0.9853 - recall_5: 0.9834 - auc_10: 0.9990 - auc_11: 0.9967 - val_loss: 1.4389 - val_accuracy: 0.6429 - val_precision_5: 0.6567 - val_recall_5: 0.6286 - val_auc_10: 0.8854 - val_auc_11: 0.6926
# Epoch 145/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9849 - precision_5: 0.9853 - recall_5: 0.9842 - auc_10: 0.9990 - auc_11: 0.9974WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0445 - accuracy: 0.9849 - precision_5: 0.9853 - recall_5: 0.9842 - auc_10: 0.9990 - auc_11: 0.9974 - val_loss: 2.3607 - val_accuracy: 0.5857 - val_precision_5: 0.5942 - val_recall_5: 0.5857 - val_auc_10: 0.8829 - val_auc_11: 0.6319
# Epoch 146/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9777 - precision_5: 0.9785 - recall_5: 0.9774 - auc_10: 0.9992 - auc_11: 0.9973WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0606 - accuracy: 0.9777 - precision_5: 0.9785 - recall_5: 0.9774 - auc_10: 0.9992 - auc_11: 0.9973 - val_loss: 3.2423 - val_accuracy: 0.5857 - val_precision_5: 0.5797 - val_recall_5: 0.5714 - val_auc_10: 0.8293 - val_auc_11: 0.5256
# Epoch 147/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9777 - precision_5: 0.9789 - recall_5: 0.9777 - auc_10: 0.9988 - auc_11: 0.9958WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0695 - accuracy: 0.9777 - precision_5: 0.9789 - recall_5: 0.9777 - auc_10: 0.9988 - auc_11: 0.9958 - val_loss: 2.9744 - val_accuracy: 0.5857 - val_precision_5: 0.5797 - val_recall_5: 0.5714 - val_auc_10: 0.8323 - val_auc_11: 0.5567
# Epoch 148/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9770 - precision_5: 0.9770 - recall_5: 0.9762 - auc_10: 0.9993 - auc_11: 0.9973WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0654 - accuracy: 0.9770 - precision_5: 0.9770 - recall_5: 0.9762 - auc_10: 0.9993 - auc_11: 0.9973 - val_loss: 1.3979 - val_accuracy: 0.6857 - val_precision_5: 0.7273 - val_recall_5: 0.6857 - val_auc_10: 0.9074 - val_auc_11: 0.7555
# Epoch 149/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9774 - precision_5: 0.9792 - recall_5: 0.9770 - auc_10: 0.9989 - auc_11: 0.9965WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 31s 1s/step - loss: 0.0649 - accuracy: 0.9774 - precision_5: 0.9792 - recall_5: 0.9770 - auc_10: 0.9989 - auc_11: 0.9965 - val_loss: 2.8073 - val_accuracy: 0.5714 - val_precision_5: 0.5714 - val_recall_5: 0.5714 - val_auc_10: 0.8113 - val_auc_11: 0.5246
# Epoch 150/150
# 27/27 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9747 - precision_5: 0.9766 - recall_5: 0.9743 - auc_10: 0.9989 - auc_11: 0.9962WARNING:tensorflow:Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: loss,accuracy,precision_5,recall_5,auc_10,auc_11,val_loss,val_accuracy,val_precision_5,val_recall_5,val_auc_10,val_auc_11
# 27/27 [==============================] - 30s 1s/step - loss: 0.0708 - accuracy: 0.9747 - precision_5: 0.9766 - recall_5: 0.9743 - auc_10: 0.9989 - auc_11: 0.9962 - val_loss: 2.1762 - val_accuracy: 0.5857 - val_precision_5: 0.5735 - val_recall_5: 0.5571 - val_auc_10: 0.8192 - val_auc_11: 0.5862

# %%
eval__val_recall_weighted = model_val_recall_weighted.evaluate(testgenerator) #early stopping - val_recall
# Out:
# 7/7 [==============================] - 7s 1s/step - loss: 2.3258 - accuracy: 0.4947 - precision_5: 0.5024 - recall_5: 0.4765 - auc_10: 0.8077 - auc_11: 0.4975

# %%
history1_df = pd.DataFrame(history_val_loss_weighted.history)
history2_df = pd.DataFrame(history_val_accuracy.history)
history3_df = pd.DataFrame(history_val_accuracy_weighted.history)
history4_df = pd.DataFrame(history_val_recall.history)
history5_df = pd.DataFrame(history_val_recall_weighted.history)
from google.colab import files
history_df.to_csv('history_val_loss.csv')
history1_df.to_csv('history_val_loss_weighted.csv')
history2_df.to_csv('history_val_accuracy.csv')
history3_df.to_csv('history_val_accuracy_weighted.csv')
history4_df.to_csv('history_val_recall.csv')
history5_df.to_csv('history_val_recall_weighted.csv')

files.download('history_val_loss.csv')
files.download('history_val_loss_weighted.csv')
files.download('history_val_accuracy.csv')
files.download('history_val_accuracy_weighted.csv')
files.download('history_val_recall.csv')
files.download('history_val_recall_weighted.csv')

# %% [markdown]
# val_loss plots

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_loss.history['accuracy'])
plt.plot(history_val_loss.history['val_accuracy'])
plt.plot(history_val_loss.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])

# %%
plt.plot(history_val_loss.history['loss'])
plt.plot(history_val_loss.history['val_loss'])

# %% [markdown]
# val_loss - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_loss_weighted.history['accuracy'])
plt.plot(history_val_loss_weighted.history['val_accuracy'])
plt.plot(history_val_loss_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-a8957391caac> in <module>()
#       3 plt.plot(history_val_loss_weighted.history['accuracy'])
#       4 plt.plot(history_val_loss_weighted.history['val_accuracy'])
# ----> 5 plt.plot(history_val_loss_weighted.history['val_recall'])
#       6 plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
#
# KeyError: 'val_recall'

# %%
plt.plot(history_val_loss_weighted.history['loss'])
plt.plot(history_val_loss_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_accuracy.history['accuracy'])
plt.plot(history_val_accuracy.history['val_accuracy'])
plt.plot(history_val_accuracy.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-376eb9904c94> in <module>()
#       3 plt.plot(history_val_accuracy.history['accuracy'])
#       4 plt.plot(history_val_accuracy.history['val_accuracy'])
# ----> 5 plt.plot(history_val_accuracy.history['val_recall'])
#       6 plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
#
# KeyError: 'val_recall'

# %%
plt.plot(history_val_accuracy.history['loss'])
plt.plot(history_val_accuracy.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_accuracy - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_accuracy_weighted.history['accuracy'])
plt.plot(history_val_accuracy_weighted.history['val_accuracy'])
plt.plot(history_val_accuracy_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-8e25d203a735> in <module>()
#       3 plt.plot(history_val_accuracy_weighted.history['accuracy'])
#       4 plt.plot(history_val_accuracy_weighted.history['val_accuracy'])
# ----> 5 plt.plot(history_val_accuracy_weighted.history['val_recall'])
#       6 plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
#
# KeyError: 'val_recall'

# %%
plt.plot(history_val_accuracy_weighted.history['loss'])
plt.plot(history_val_accuracy_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_recall

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_recall.history['accuracy'])
plt.plot(history_val_recall.history['val_accuracy'])
plt.plot(history_val_recall.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-16af87dcd1b3> in <module>()
#       3 plt.plot(history_val_recall.history['accuracy'])
#       4 plt.plot(history_val_recall.history['val_accuracy'])
# ----> 5 plt.plot(history_val_recall.history['val_recall'])
#       6 plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
#
# KeyError: 'val_recall'

# %%
plt.plot(history_val_recall.history['loss'])
plt.plot(history_val_recall.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %% [markdown]
# val_recall - weighted

# %%
import matplotlib.pyplot as plt

plt.plot(history_val_recall_weighted.history['accuracy'])
plt.plot(history_val_recall_weighted.history['val_accuracy'])
plt.plot(history_val_recall_weighted.history['val_recall'])
plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-b04c5579fb73> in <module>()
#       3 plt.plot(history_val_recall_weighted.history['accuracy'])
#       4 plt.plot(history_val_recall_weighted.history['val_accuracy'])
# ----> 5 plt.plot(history_val_recall_weighted.history['val_recall'])
#       6 plt.legend(['Accuracy', 'Validation Accuracy', 'Validation Recall'])
#
# KeyError: 'val_recall'

# %%
plt.plot(history_val_recall_weighted.history['loss'])
plt.plot(history_val_recall_weighted.history['val_loss'])
plt.legend(['Loss', 'Validation Loss'])

# %%
np.save('early_stopping__val_loss_custom_weights_history.npy',history.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-58c543d27dbd> in <module>()
# ----> 1 np.save('early_stopping__val_loss_custom_weights_history.npy',history.history)
#
# NameError: name 'history' is not defined

# %%
history=np.load('50epoch-no_custom_weights_history.npy',allow_pickle='TRUE').item()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-1c9e23f5f7f8> in <module>()
# ----> 1 history=np.load('50epoch-no_custom_weights_history.npy',allow_pickle='TRUE').item()
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '50epoch-no_custom_weights_history.npy'

# %%
model_val_loss.save("early_stopping__val_loss_custom_weights")
# Out:
# INFO:tensorflow:Assets written to: early_stopping__val_loss_custom_weights/assets

# %%
np.save('early_stopping__val_accuracy_custom_weights_history.npy',history.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-460f92bfe45a> in <module>()
# ----> 1 np.save('early_stopping__val_accuracy_custom_weights_history.npy',history.history)
#
# NameError: name 'history' is not defined

# %%
model_val_accuracy.save("early_stopping__val_accuracy_custom_weights")

# %%
np.save('early_stopping__val_recall_custom_weights_history.npy',history.history)

# %%
model_val_recall.save("early_stopping__val_recall_custom_weights")
# Out:
# INFO:tensorflow:Assets written to: early_stopping__val_recall_custom_weights/assets

# %%
# !zip -r recall_early_stop-no_custom_weights.zip recall_early_stop-no_custom_weights
# Out:
# 	zip warning: name not matched: recall_early_stop-no_custom_weights
#
# zip error: Nothing to do! (try: zip -r recall_early_stop-no_custom_weights.zip . -i recall_early_stop-no_custom_weights)

# %%
# !unzip /content/early-stop-val_recall-custom_weights.zip
# Out:
# unzip:  cannot find or open /content/early-stop-val_recall-custom_weights.zip, /content/early-stop-val_recall-custom_weights.zip.zip or /content/early-stop-val_recall-custom_weights.zip.ZIP.

# %%
# !mv /content/early-stop-val_recall-custom_weights/* /content
# Out:
# mv: cannot stat '/content/early-stop-val_recall-custom_weights/*': No such file or directory

# %%
model = tf.keras.models.load_model("early-stop-val_recall-custom_weights")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-53-520acb6fa5a4> in <module>()
# ----> 1 model = tf.keras.models.load_model("early-stop-val_recall-custom_weights")
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     207         if isinstance(filepath, str):
#     208           if not tf.io.gfile.exists(filepath):
# --> 209             raise IOError(f'No file or directory found at {filepath}')
#     210           if saving_utils.is_hdf5_filepath(filepath) and h5py is None:
#     211             raise ImportError(
#
# OSError: No file or directory found at early-stop-val_recall-custom_weights

# %% [markdown]
# List of Convolutional Layers in the model

# %%
for layer in model.layers:
  if 'conv' in layer.name:
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-46acca41d29d> in <module>()
# ----> 1 for layer in model.layers:
#       2   if 'conv' in layer.name:
#       3     filters, biases = layer.get_weights()
#       4     print(layer.name, filters.shape)
#
# NameError: name 'model' is not defined

# %%
filters, biases = model.layers[0].get_weights()
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)
n_filters, ix = filters.shape[-1], 1
for i in range(n_filters):
  # get the filter
  f = filters[:, :, :, i]
  # plot each channel separately
  for j in range(3):
    # specify subplot and turn of axis
    ax = plt.subplot(n_filters, 3, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    plt.imshow(f[:, :, j], cmap='gray')
    ix += 1
# show the figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-59eaca3a8963> in <module>()
# ----> 1 filters, biases = model.layers[0].get_weights()
#       2 f_min, f_max = filters.min(), filters.max()
#       3 filters = (filters - f_min) / (f_max - f_min)
#       4 n_filters, ix = filters.shape[-1], 1
#       5 for i in range(n_filters):
#
# NameError: name 'model' is not defined

# %%
test_file_names = testgenerator.filenames
sample_indexes = []
class_index_keys = list(class_index.keys())
for j in range(len(class_index_keys)):
  for i in range(len(test_file_names)):
    if test_file_names[i][test_file_names[i].find(class_index_keys[j]):len(class_index_keys[j])]: 
      sample_indexes.append(i)
      break

sample_AKIEC = "Train/" + test_file_names[sample_indexes[0]]
sample_BCC   = "Train/" + test_file_names[sample_indexes[1]]
sample_BKL   = "Train/" + test_file_names[sample_indexes[2]]
sample_DF    = "Train/" + test_file_names[sample_indexes[3]]
sample_MEL   = "Train/" + test_file_names[sample_indexes[4]]
sample_NV    = "Train/" + test_file_names[sample_indexes[5]]
sample_VASC  = "Train/" + test_file_names[sample_indexes[6]]

# %%
pyplot.rcParams['figure.figsize'] = [30, 5]

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot
from numpy import expand_dims
# load the model
ixs = [0, 3, 6, 7, 10, 11]
outputs = [model.layers[i+1].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
# load the image with the required shape
img = load_img(sample_AKIEC, target_size=(75, 100), color_mode='rgb')
# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)

# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot the output from each block
for fmap in feature_maps:
  # plot all 64 maps in an 8x8 squares
  ix = 1
  dim = fmap.shape[-1]
  #	for _ in range(square):
  for _ in range(dim):
    # specify subplot and turn of axis
    ax = pyplot.subplot(1, dim, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(fmap[0, :, :, ix-1])
    ix += 1
	# show the figure
  #pyplot.gcf().set_size_inches(10,50)
  pyplot.show()

# %%
traingenerator.next()
